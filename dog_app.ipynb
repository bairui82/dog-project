# %% [markdown]
# ## 卷积神经网络（Convolutional Neural Network, CNN）
#
# ## 项目：实现一个狗品种识别算法App
#
# 在这个notebook文件中，有些模板代码已经提供给你，但你还需要实现更多的功能来完成这个项目。除非有明确要求，你无须修改任何已给出的代码。以**'(练习)'**开始的标题表示接下来的代码部分中有你需要实现的功能。这些部分都配有详细的指导，需要实现的部分也会在注释中以'TODO'标出。请仔细阅读所有的提示。
#
# 除了实现代码外，你还**需要**回答一些与项目及代码相关的问题。每个需要回答的问题都会以 **'问题 X'** 标记。请仔细阅读每个问题，并且在问题后的 **'回答'** 部分写出完整的答案。我们将根据 你对问题的回答 和 撰写代码实现的功能 来对你提交的项目进行评分。
#
# >**提示：**Code 和 Markdown 区域可通过 **Shift + Enter** 快捷键运行。此外，Markdown可以通过双击进入编辑模式。
#
# 项目中显示为_选做_的部分可以帮助你的项目脱颖而出，而不是仅仅达到通过的最低要求。如果你决定追求更高的挑战，请在此 notebook 中完成_选做_部分的代码。
#
# ---
#
# ### 让我们开始吧
# 在这个notebook中，你将迈出第一步，来开发可以作为移动端或 Web应用程序一部分的算法。在这个项目的最后，你的程序将能够把用户提供的任何一个图像作为输入。如果可以从图像中检测到一只狗，它会输出对狗品种的预测。如果图像中是一个人脸，它会预测一个与其最相似的狗的种类。下面这张图展示了完成项目后可能的输出结果。（……实际上我们希望每个学生的输出结果不相同！）
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# 在现实世界中，你需要拼凑一系列的模型来完成不同的任务；举个例子，用来预测狗种类的算法会与预测人类的算法不同。在做项目的过程中，你可能会遇到不少失败的预测，因为并不存在完美的算法和模型。你最终提交的不完美的解决方案也一定会给你带来一个有趣的学习经验！
#
# ### 项目内容
#
# 我们将这个notebook分为不同的步骤，你可以使用下面的链接来浏览此notebook。
#
# * [Step 0](#step0): 导入数据集
# * [Step 1](#step1): 检测人脸
# * [Step 2](#step2): 检测狗狗
# * [Step 3](#step3): 从头创建一个CNN来分类狗品种
# * [Step 4](#step4): 使用一个CNN来区分狗的品种(使用迁移学习)
# * [Step 5](#step5): 建立一个CNN来分类狗的品种（使用迁移学习）
# * [Step 6](#step6): 完成你的算法
# * [Step 7](#step7): 测试你的算法
#
# 在该项目中包含了如下的问题：
#
# * [问题 1](#question1)
# * [问题 2](#question2)
# * [问题 3](#question3)
# * [问题 4](#question4)
# * [问题 5](#question5)
# * [问题 6](#question6)
# * [问题 7](#question7)
# * [问题 8](#question8)
# * [问题 9](#question9)
# * [问题 10](#question10)
# * [问题 11](#question11)
#
#
# ---
# <a id='step0'></a>
# ## 步骤 0: 导入数据集
#
# ### 导入狗数据集
# 在下方的代码单元（cell）中，我们导入了一个狗图像的数据集。我们使用 scikit-learn 库中的 `load_files` 函数来获取一些变量：
# - `train_files`, `valid_files`, `test_files` - 包含图像的文件路径的numpy数组
# - `train_targets`, `valid_targets`, `test_targets` - 包含独热编码分类标签的numpy数组
# - `dog_names` - 由字符串构成的与标签相对应的狗的种类

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# 定义函数来加载train，test和validation数据集
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# 加载train，test和validation数据集
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# 加载狗品种列表
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# 打印数据统计描述
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %%
import random
random.seed(8675309)

# 加载打乱后的人脸数据集的文件名
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# 打印数据集的数据量
print('There are %d total human images.' % len(human_files))

"""---
<a id='step1'></a>
## 步骤1：检测人脸
 
我们将使用 OpenCV 中的 [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) 来检测图像中的人脸。OpenCV 提供了很多预训练的人脸检测模型，它们以XML文件保存在 [github](https://github.com/opencv/opencv/tree/master/data/haarcascades)。我们已经下载了其中一个检测模型，并且把它存储在 `haarcascades` 的目录中。

在如下代码单元中，我们将演示如何使用这个检测模型在样本图像中找到人脸。"""


import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# 提取预训练的人脸检测模型
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# 加载彩色（通道顺序为BGR）图像
img = cv2.imread(human_files[3])

# 将BGR图像进行灰度处理
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 在图像中找出脸
faces = face_cascade.detectMultiScale(gray)

# 打印图像中检测到的脸的个数
print('Number of faces detected:', len(faces))

# 获取每一个所检测到的脸的识别框
for (x,y,w,h) in faces:
    # 在人脸图像中绘制出识别框
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# 将BGR图像转变为RGB图像以打印
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 展示含有识别框的图像
plt.imshow(cv_rgb)
plt.show()
# Out:
# There are 13234 total human images.
# Number of faces detected: 1

# %% [markdown]
# ### 导入人脸数据集
#
# 在下方的代码单元中，我们导入人脸图像数据集，文件所在路径存储在名为 `human_files` 的 numpy 数组。

# %%
import random
random.seed(8675309)

# 加载打乱后的人脸数据集的文件名
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# 打印数据集的数据量
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13234 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## 步骤1：检测人脸
#
# 我们将使用 OpenCV 中的 [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) 来检测图像中的人脸。OpenCV 提供了很多预训练的人脸检测模型，它们以XML文件保存在 [github](https://github.com/opencv/opencv/tree/master/data/haarcascades)。我们已经下载了其中一个检测模型，并且把它存储在 `haarcascades` 的目录中。
#
# 在如下代码单元中，我们将演示如何使用这个检测模型在样本图像中找到人脸。

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# 提取预训练的人脸检测模型
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# 加载彩色（通道顺序为BGR）图像
img = cv2.imread(human_files[3])

# 将BGR图像进行灰度处理
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 在图像中找出脸
faces = face_cascade.detectMultiScale(gray)

# 打印图像中检测到的脸的个数
print('Number of faces detected:', len(faces))

# 获取每一个所检测到的脸的识别框
for (x,y,w,h) in faces:
    # 在人脸图像中绘制出识别框
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# 将BGR图像转变为RGB图像以打印
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 展示含有识别框的图像
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# 在使用任何一个检测模型之前，将图像转换为灰度图是常用过程。`detectMultiScale` 函数使用储存在 `face_cascade` 中的的数据，对输入的灰度图像进行分类。
#
# 在上方的代码中，`faces` 以 numpy 数组的形式，保存了识别到的面部信息。它其中每一行表示一个被检测到的脸，该数据包括如下四个信息：前两个元素  `x`、`y` 代表识别框左上角的 x 和 y 坐标（参照上图，注意 y 坐标的方向和我们默认的方向不同）；后两个元素代表识别框在 x 和 y 轴两个方向延伸的长度 `w` 和 `d`。
#
# ### 写一个人脸识别器
#
# 我们可以将这个程序封装为一个函数。该函数的输入为人脸图像的**路径**，当图像中包含人脸时，该函数返回 `True`，反之返回 `False`。该函数定义如下所示。

# %%
# 如果img_path路径表示的图像检测到了脸，返回"True" 
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### **【练习】** 评估人脸检测模型

# %% [markdown]
# ---
#
# <a id='question1'></a>
# ### __问题 1:__
#
# 在下方的代码块中，使用 `face_detector` 函数，计算：
#
# - `human_files` 的前100张图像中，能够检测到**人脸**的图像占比多少？
# - `dog_files` 的前100张图像中，能够检测到**人脸**的图像占比多少？
#
# 理想情况下，人图像中检测到人脸的概率应当为100%，而狗图像中检测到人脸的概率应该为0%。你会发现我们的算法并非完美，但结果仍然是可以接受的。我们从每个数据集中提取前100个图像的文件路径，并将它们存储在`human_files_short`和`dog_files_short`中。

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
## 请不要修改上方代码


## TODO: 基于human_files_short和dog_files_short
## 中的图像测试face_detector的表现
def get_detector_percentage(detector, data_files):
    return np.mean([detector(f) for f in data_files])
print('人脸识别正确率: {:.2%}'.format(get_detector_percentage(face_detector, human_files_short)))
print('狗图像识别错误率: {:.2%}'.format(get_detector_percentage(face_detector, dog_files_short)))
# Out:
# 人脸识别正确率: 97.00%
# 狗图像识别错误率: 11.00%

# %% [markdown]
# ---
#
# <a id='question2'></a>
#
# ### __问题 2:__
#
# 就算法而言，该算法成功与否的关键在于，用户能否提供含有清晰面部特征的人脸图像。
# 那么你认为，这样的要求在实际使用中对用户合理吗？如果你觉得不合理，你能否想到一个方法，即使图像中并没有清晰的面部特征，也能够检测到人脸？
#
# __回答:__ 我认为这样的要求在实际使用中对用户不太合理.在实际使用中,例如实时用摄像头识别人脸,当人侧面时容易丢失,假如能通过识别眼睛,鼻子,嘴巴,类似的细节,然后通过限定其在一定范围内,应该也能够识别人脸.

# %% [markdown]
# ---
#
# <a id='Selection1'></a>
# ### 选做：
#
# 我们建议在你的算法中使用opencv的人脸检测模型去检测人类图像，不过你可以自由地探索其他的方法，尤其是尝试使用深度学习来解决它:)。请用下方的代码单元来设计和测试你的面部监测算法。如果你决定完成这个_选做_任务，你需要报告算法在每一个数据集上的表现。

# %%
## (选做) TODO: 报告另一个面部检测算法在LFW数据集上的表现
### 你可以随意使用所需的代码单元数

# %% [markdown]
# ---
# <a id='step2'></a>
#
# ## 步骤 2: 检测狗狗
#
# 在这个部分中，我们使用预训练的 [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) 模型去检测图像中的狗。下方的第一行代码就是下载了 ResNet-50 模型的网络结构参数，以及基于 [ImageNet](http://www.image-net.org/) 数据集的预训练权重。
#
# ImageNet 这目前一个非常流行的数据集，常被用来测试图像分类等计算机视觉任务相关的算法。它包含超过一千万个 URL，每一个都链接到 [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a) 中所对应的一个物体的图像。任给输入一个图像，该 ResNet-50 模型会返回一个对图像中物体的预测结果。

# %%
from keras.applications.resnet50 import ResNet50

# 定义ResNet50模型
ResNet50_model = ResNet50(weights='imagenet')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\TF-GPU\lib\site-packages\keras\backend\tensorflow_backend.py:1062: calling reduce_prod (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# ### 数据预处理
#
# - 在使用 TensorFlow 作为后端的时候，在 Keras 中，CNN 的输入是一个4维数组（也被称作4维张量），它的各维度尺寸为 `(nb_samples, rows, columns, channels)`。其中 `nb_samples` 表示图像（或者样本）的总数，`rows`, `columns`, 和 `channels` 分别表示图像的行数、列数和通道数。
#
#
# - 下方的 `path_to_tensor` 函数实现如下将彩色图像的字符串型的文件路径作为输入，返回一个4维张量，作为 Keras CNN 输入。因为我们的输入图像是彩色图像，因此它们具有三个通道（ `channels` 为 `3`）。
#     1. 该函数首先读取一张图像，然后将其缩放为 224×224 的图像。
#     2. 随后，该图像被调整为具有4个维度的张量。
#     3. 对于任一输入图像，最后返回的张量的维度是：`(1, 224, 224, 3)`。
#
#
# - `paths_to_tensor` 函数将图像路径的字符串组成的 numpy 数组作为输入，并返回一个4维张量，各维度尺寸为 `(nb_samples, 224, 224, 3)`。 在这里，`nb_samples`是提供的图像路径的数据中的样本数量或图像数量。你也可以将 `nb_samples` 理解为数据集中3维张量的个数（每个3维张量表示一个不同的图像。

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # 用PIL加载RGB图像为PIL.Image.Image类型
    img = image.load_img(img_path, target_size=(224, 224))
    # 将PIL.Image.Image类型转化为格式为(224, 224, 3)的3维张量
    x = image.img_to_array(img)
    # 将3维张量转化为格式为(1, 224, 224, 3)的4维张量并返回
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### 基于 ResNet-50 架构进行预测
#
# 对于通过上述步骤得到的四维张量，在把它们输入到 ResNet-50 网络、或 Keras 中其他类似的预训练模型之前，还需要进行一些额外的处理：
# 1. 首先，这些图像的通道顺序为 RGB，我们需要重排他们的通道顺序为 BGR。
# 2. 其次，预训练模型的输入都进行了额外的归一化过程。因此我们在这里也要对这些张量进行归一化，即对所有图像所有像素都减去像素均值 `[103.939, 116.779, 123.68]`（以 RGB 模式表示，根据所有的 ImageNet 图像算出）。
#
# 导入的 `preprocess_input` 函数实现了这些功能。如果你对此很感兴趣，可以在 [这里](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py) 查看 `preprocess_input`的代码。
#
#
# 在实现了图像处理的部分之后，我们就可以使用模型来进行预测。这一步通过 `predict` 方法来实现，它返回一个向量，向量的第 i 个元素表示该图像属于第 i 个 ImageNet 类别的概率。这通过如下的 `ResNet50_predict_labels` 函数实现。
#
# 通过对预测出的向量取用 argmax 函数（找到有最大概率值的下标序号），我们可以得到一个整数，即模型预测到的物体的类别。进而根据这个 [清单](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a)，我们能够知道这具体是哪个品种的狗狗。

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions
def ResNet50_predict_labels(img_path):
    # 返回img_path路径的图像的预测向量
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### 完成狗检测模型
#
#
# 在研究该 [清单](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a) 的时候，你会注意到，狗类别对应的序号为151-268。因此，在检查预训练模型判断图像是否包含狗的时候，我们只需要检查如上的 `ResNet50_predict_labels` 函数是否返回一个介于151和268之间（包含区间端点）的值。
#
# 我们通过这些想法来完成下方的 `dog_detector` 函数，如果从图像中检测到狗就返回 `True`，否则返回 `False`。

# %%
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### 【作业】评估狗狗检测模型
#
# ---
#
# <a id='question3'></a>
# ### __问题 3:__
#
# 在下方的代码块中，使用 `dog_detector` 函数，计算：
#
# - `human_files_short`中图像检测到狗狗的百分比？
# - `dog_files_short`中图像检测到狗狗的百分比？

# %%
### TODO: 测试dog_detector函数在human_files_short和dog_files_short的表现
print('人脸图像识别出狗狗率: {:.2%}'.format(get_detector_percentage(dog_detector, human_files_short)))
print('狗图像识别狗狗率: {:.2%}'.format(get_detector_percentage(dog_detector, dog_files_short)))
# Out:
# 人脸图像识别出狗狗率: 2.00%
# 狗图像识别狗狗率: 100.00%

# %% [markdown]
# ---
#
# <a id='step3'></a>
#
# ## 步骤 3: 从头开始创建一个CNN来分类狗品种
#
#
# 现在我们已经实现了一个函数，能够在图像中识别人类及狗狗。但我们需要更进一步的方法，来对狗的类别进行识别。在这一步中，你需要实现一个卷积神经网络来对狗的品种进行分类。你需要__从头实现__你的卷积神经网络（在这一阶段，你还不能使用迁移学习），并且你需要达到超过1%的测试集准确率。在本项目的步骤五种，你还有机会使用迁移学习来实现一个准确率大大提高的模型。
#
# 在添加卷积层的时候，注意不要加上太多的（可训练的）层。更多的参数意味着更长的训练时间，也就是说你更可能需要一个 GPU 来加速训练过程。万幸的是，Keras 提供了能够轻松预测每次迭代（epoch）花费时间所需的函数。你可以据此推断你算法所需的训练时间。
#
# 值得注意的是，对狗的图像进行分类是一项极具挑战性的任务。因为即便是一个正常人，也很难区分布列塔尼犬和威尔士史宾格犬。
#
#
# 布列塔尼犬（Brittany） | 威尔士史宾格犬（Welsh Springer Spaniel）
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# 不难发现其他的狗品种会有很小的类间差别（比如金毛寻回犬和美国水猎犬）。
#
#
# 金毛寻回犬（Curly-Coated Retriever） | 美国水猎犬（American Water Spaniel）
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
# 同样，拉布拉多犬（labradors）有黄色、棕色和黑色这三种。那么你设计的基于视觉的算法将不得不克服这种较高的类间差别，以达到能够将这些不同颜色的同类狗分到同一个品种中。
#
# 黄色拉布拉多犬（Yellow Labrador） | 棕色拉布拉多犬（Chocolate Labrador） | 黑色拉布拉多犬（Black Labrador）
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# 我们也提到了随机分类将得到一个非常低的结果：不考虑品种略有失衡的影响，随机猜测到正确品种的概率是1/133，相对应的准确率是低于1%的。
#
# 请记住，在深度学习领域，实践远远高于理论。大量尝试不同的框架吧，相信你的直觉！当然，玩得开心！
#
#
# ### 数据预处理
#
#
# 通过对每张图像的像素值除以255，我们对图像实现了归一化处理。

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                  

# Keras中的数据预处理过程
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6680/6680 [00:51<00:00, 129.78it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 835/835 [00:05<00:00, 162.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 836/836 [00:05<00:00, 143.25it/s]

# %% [markdown]
# ### 【练习】模型架构
#
#
# 创建一个卷积神经网络来对狗品种进行分类。在你代码块的最后，执行 `model.summary()` 来输出你模型的总结信息。
#
# 我们已经帮你导入了一些所需的 Python 库，如有需要你可以自行导入。如果你在过程中遇到了困难，如下是给你的一点小提示——该模型能够在5个 epoch 内取得超过1%的测试准确率，并且能在CPU上很快地训练。
#
# ![Sample CNN](images/sample_cnn.png)

# %% [markdown]
# ---
#
# <a id='question4'></a>
#
# ### __问题 4:__
#
# 在下方的代码块中尝试使用 Keras 搭建卷积网络的架构，并回答相关的问题。
#
# 1. 你可以尝试自己搭建一个卷积网络的模型，那么你需要回答你搭建卷积网络的具体步骤（用了哪些层）以及为什么这样搭建。
# 2. 你也可以根据上图提示的步骤搭建卷积网络，那么请说明为何如上的架构能够在该问题上取得很好的表现。
#
# __回答:__ 首先添加了一个BatchNoramlization（BN层）BN解决了反向传播过程中的梯度问题（梯度消失和爆炸），同时使得不同scale的 w 整体更新步调更一致。by Jiang https://www.zhihu.com/question/38102762 对过拟合也有一定的缓解
#           其次一个2*2的卷积层 这个卷积层决定了一开始模型会学习什么，我选择了2*2的大小，这样整个网络会先学习细微的特征
#           然后是一个12*12，步长为12*12的池化层，这个池化层属于一般池化，选择12*12为的是快速的下降维度保留一定特征，然后今天快速学习。
#           接着是两组卷积池化，分别是一个2*2的卷积层，因为先前已经通过池化将图形特征保留在一个较小维度中，所以通过这个2*2的卷积层相当与一个卷积有之前原图25*25大小的信息量，通过这个大小找较大特征来分类。
#           一个2*2步长为2*2的池化层 用来减小输出大小和避免过拟合
#           最后是一个globalaveragepooling（全局平均池化） 对整个网路在结构上做正则化防止过拟合 by williamyi96 https://blog.csdn.net/williamyi96/article/details/77530995
#           和一个用softmax做激活函数的Dense层，做到将数据分到133个类中

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Activation,Dropout, Flatten, Dense, BatchNormalization
from keras.models import Sequential
import tensorflow as tf
model = Sequential()
model.add(BatchNormalization(
    axis=-1,
    momentum=0.99,
    epsilon=0.001,
    center=True,
    scale=True,
    beta_initializer='zeros',
    gamma_initializer='ones',
    moving_mean_initializer='zeros',
    moving_variance_initializer='ones',
    beta_regularizer=None,
    gamma_regularizer=None,
    beta_constraint=None,
    gamma_constraint=None,
    input_shape=(224,224,3),
    name='BN_layer1'
))
model.add(Conv2D(
    filters=16,
    kernel_size=(2,2),
    strides=(1, 1),
    padding='valid',
    data_format='channels_last',
    bias_initializer=tf.zeros_initializer(),
    name='conv2d_1'
))
model.add(MaxPooling2D(
    pool_size=(12,12),
    strides=(12, 12),
    padding='valid',
    data_format='channels_last',
    name='max_pooling2d_1'
))
model.add(Conv2D(
    32,
    (2,2),
    strides=(1, 1),
    padding='valid',
    data_format='channels_last',
    bias_initializer=tf.zeros_initializer(),
    name='conv2d_2'
))
model.add(MaxPooling2D(
    pool_size=(2,2),
    strides=(2, 2),
    padding='valid',
    data_format='channels_last',
    name='max_pooling2d_2'
))
model.add(Conv2D(
    64,
    (2,2),
    strides=(1, 1),
    padding='valid',
    data_format='channels_last',
    bias_initializer=tf.zeros_initializer(),
    name='conv2d_3'
))
model.add(MaxPooling2D(
    pool_size=(2,2),
    strides=(2, 2),
    padding='valid',
    data_format='channels_last',
    name='max_pooling2d_3'
))

model.add(GlobalAveragePooling2D(
    data_format='channels_last',
    name='global_average_pooling2d_1'
))
model.add(Dense(
    133,
    activation="softmax",
    kernel_initializer='glorot_uniform',
    bias_initializer='zeros',
    name='dense_1'
))
### TODO: 定义你的网络架构
                 
model.summary()
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\TF-GPU\lib\site-packages\keras\backend\tensorflow_backend.py:1123: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# BN_layer1 (BatchNormalizatio (None, 224, 224, 3)       12
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 223, 223, 16)      208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 18, 18, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 17, 17, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               8645
# =================================================================
# Total params: 19,201.0
# Trainable params: 19,195.0
# Non-trainable params: 6.0
# _________________________________________________________________

# %%
## 编译模型
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\TF-GPU\lib\site-packages\keras\backend\tensorflow_backend.py:2548: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# ---

# %% [markdown]
# ## 【练习】训练模型
#
#
# ---
#
# <a id='question5'></a>
#
# ### __问题 5:__
#
# 在下方代码单元训练模型。使用模型检查点（model checkpointing）来储存具有最低验证集 loss 的模型。
#
# 可选题：你也可以对训练集进行 [数据增强](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html)，来优化模型的表现。

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: 设置训练模型的epochs的数量

epochs = 10

### 不要修改下方代码

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model_history = model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/10
# 6660/6680 [============================>.] - ETA: 158s - loss: 4.9685 - acc: 0.0000e+0 - ETA: 44s - loss: 5.0078 - acc: 0.0000e+0 - ETA: 28s - loss: 4.9572 - acc: 0.0000e+ - ETA: 22s - loss: 4.9456 - acc: 0.0000e+ - ETA: 18s - loss: 4.9380 - acc: 0.0000e+ - ETA: 16s - loss: 4.9311 - acc: 0.0063   - ETA: 14s - loss: 4.9261 - acc: 0.00 - ETA: 13s - loss: 4.9204 - acc: 0.00 - ETA: 12s - loss: 4.9211 - acc: 0.00 - ETA: 11s - loss: 4.9149 - acc: 0.00 - ETA: 11s - loss: 4.9149 - acc: 0.00 - ETA: 10s - loss: 4.9079 - acc: 0.01 - ETA: 10s - loss: 4.9071 - acc: 0.00 - ETA: 9s - loss: 4.9091 - acc: 0.0088 - ETA: 9s - loss: 4.9030 - acc: 0.008 - ETA: 9s - loss: 4.9010 - acc: 0.008 - ETA: 8s - loss: 4.8996 - acc: 0.010 - ETA: 8s - loss: 4.9011 - acc: 0.011 - ETA: 8s - loss: 4.8979 - acc: 0.011 - ETA: 8s - loss: 4.8957 - acc: 0.012 - ETA: 8s - loss: 4.8952 - acc: 0.012 - ETA: 7s - loss: 4.8965 - acc: 0.011 - ETA: 7s - loss: 4.8930 - acc: 0.012 - ETA: 7s - loss: 4.8925 - acc: 0.012 - ETA: 7s - loss: 4.8916 - acc: 0.012 - ETA: 7s - loss: 4.8914 - acc: 0.011 - ETA: 7s - loss: 4.8917 - acc: 0.011 - ETA: 6s - loss: 4.8901 - acc: 0.012 - ETA: 6s - loss: 4.8900 - acc: 0.012 - ETA: 6s - loss: 4.8884 - acc: 0.011 - ETA: 6s - loss: 4.8866 - acc: 0.012 - ETA: 6s - loss: 4.8858 - acc: 0.013 - ETA: 6s - loss: 4.8861 - acc: 0.013 - ETA: 6s - loss: 4.8838 - acc: 0.014 - ETA: 6s - loss: 4.8820 - acc: 0.014 - ETA: 5s - loss: 4.8814 - acc: 0.014 - ETA: 5s - loss: 4.8805 - acc: 0.014 - ETA: 5s - loss: 4.8804 - acc: 0.014 - ETA: 5s - loss: 4.8790 - acc: 0.014 - ETA: 5s - loss: 4.8780 - acc: 0.014 - ETA: 5s - loss: 4.8768 - acc: 0.014 - ETA: 5s - loss: 4.8777 - acc: 0.014 - ETA: 5s - loss: 4.8768 - acc: 0.014 - ETA: 5s - loss: 4.8761 - acc: 0.014 - ETA: 5s - loss: 4.8748 - acc: 0.014 - ETA: 5s - loss: 4.8736 - acc: 0.015 - ETA: 4s - loss: 4.8729 - acc: 0.015 - ETA: 4s - loss: 4.8727 - acc: 0.015 - ETA: 4s - loss: 4.8727 - acc: 0.014 - ETA: 4s - loss: 4.8716 - acc: 0.015 - ETA: 4s - loss: 4.8713 - acc: 0.015 - ETA: 4s - loss: 4.8706 - acc: 0.015 - ETA: 4s - loss: 4.8683 - acc: 0.015 - ETA: 4s - loss: 4.8670 - acc: 0.015 - ETA: 4s - loss: 4.8654 - acc: 0.015 - ETA: 4s - loss: 4.8630 - acc: 0.014 - ETA: 4s - loss: 4.8612 - acc: 0.015 - ETA: 4s - loss: 4.8602 - acc: 0.015 - ETA: 3s - loss: 4.8584 - acc: 0.016 - ETA: 3s - loss: 4.8563 - acc: 0.016 - ETA: 3s - loss: 4.8555 - acc: 0.016 - ETA: 3s - loss: 4.8555 - acc: 0.016 - ETA: 3s - loss: 4.8545 - acc: 0.017 - ETA: 3s - loss: 4.8534 - acc: 0.017 - ETA: 3s - loss: 4.8513 - acc: 0.017 - ETA: 3s - loss: 4.8503 - acc: 0.016 - ETA: 3s - loss: 4.8498 - acc: 0.016 - ETA: 3s - loss: 4.8493 - acc: 0.016 - ETA: 3s - loss: 4.8494 - acc: 0.016 - ETA: 3s - loss: 4.8486 - acc: 0.016 - ETA: 2s - loss: 4.8489 - acc: 0.016 - ETA: 2s - loss: 4.8482 - acc: 0.016 - ETA: 2s - loss: 4.8459 - acc: 0.016 - ETA: 2s - loss: 4.8456 - acc: 0.016 - ETA: 2s - loss: 4.8445 - acc: 0.016 - ETA: 2s - loss: 4.8436 - acc: 0.016 - ETA: 2s - loss: 4.8430 - acc: 0.016 - ETA: 2s - loss: 4.8428 - acc: 0.016 - ETA: 2s - loss: 4.8418 - acc: 0.016 - ETA: 2s - loss: 4.8415 - acc: 0.016 - ETA: 2s - loss: 4.8414 - acc: 0.016 - ETA: 2s - loss: 4.8405 - acc: 0.016 - ETA: 2s - loss: 4.8389 - acc: 0.016 - ETA: 2s - loss: 4.8372 - acc: 0.017 - ETA: 2s - loss: 4.8373 - acc: 0.017 - ETA: 1s - loss: 4.8356 - acc: 0.017 - ETA: 1s - loss: 4.8344 - acc: 0.017 - ETA: 1s - loss: 4.8333 - acc: 0.018 - ETA: 1s - loss: 4.8307 - acc: 0.018 - ETA: 1s - loss: 4.8297 - acc: 0.018 - ETA: 1s - loss: 4.8293 - acc: 0.018 - ETA: 1s - loss: 4.8280 - acc: 0.018 - ETA: 1s - loss: 4.8273 - acc: 0.018 - ETA: 1s - loss: 4.8260 - acc: 0.018 - ETA: 1s - loss: 4.8247 - acc: 0.018 - ETA: 1s - loss: 4.8236 - acc: 0.018 - ETA: 1s - loss: 4.8208 - acc: 0.018 - ETA: 1s - loss: 4.8194 - acc: 0.018 - ETA: 1s - loss: 4.8185 - acc: 0.019 - ETA: 0s - loss: 4.8173 - acc: 0.019 - ETA: 0s - loss: 4.8165 - acc: 0.019 - ETA: 0s - loss: 4.8156 - acc: 0.019 - ETA: 0s - loss: 4.8157 - acc: 0.019 - ETA: 0s - los ...
# 6680/6680 [==============================] - 8s - loss: 4.8056 - acc: 0.0207 - val_loss: 4.7205 - val_acc: 0.0275
# Epoch 2/10
# 6620/6680 [============================>.] - ETA: 9s - loss: 4.4521 - acc: 0.0000e+0 - ETA: 7s - loss: 4.6453 - acc: 0.0125    - ETA: 7s - loss: 4.6751 - acc: 0.028 - ETA: 7s - loss: 4.6655 - acc: 0.030 - ETA: 7s - loss: 4.6447 - acc: 0.034 - ETA: 7s - loss: 4.6449 - acc: 0.034 - ETA: 7s - loss: 4.6681 - acc: 0.031 - ETA: 6s - loss: 4.6402 - acc: 0.031 - ETA: 6s - loss: 4.6501 - acc: 0.030 - ETA: 6s - loss: 4.6548 - acc: 0.032 - ETA: 6s - loss: 4.6669 - acc: 0.029 - ETA: 6s - loss: 4.6687 - acc: 0.026 - ETA: 6s - loss: 4.6799 - acc: 0.028 - ETA: 6s - loss: 4.6837 - acc: 0.031 - ETA: 6s - loss: 4.6808 - acc: 0.030 - ETA: 6s - loss: 4.6766 - acc: 0.031 - ETA: 6s - loss: 4.6719 - acc: 0.031 - ETA: 6s - loss: 4.6631 - acc: 0.030 - ETA: 6s - loss: 4.6657 - acc: 0.030 - ETA: 6s - loss: 4.6700 - acc: 0.029 - ETA: 5s - loss: 4.6680 - acc: 0.030 - ETA: 5s - loss: 4.6660 - acc: 0.032 - ETA: 5s - loss: 4.6618 - acc: 0.032 - ETA: 5s - loss: 4.6604 - acc: 0.031 - ETA: 5s - loss: 4.6625 - acc: 0.031 - ETA: 5s - loss: 4.6579 - acc: 0.030 - ETA: 5s - loss: 4.6566 - acc: 0.030 - ETA: 5s - loss: 4.6551 - acc: 0.031 - ETA: 5s - loss: 4.6482 - acc: 0.031 - ETA: 5s - loss: 4.6474 - acc: 0.034 - ETA: 5s - loss: 4.6512 - acc: 0.034 - ETA: 5s - loss: 4.6506 - acc: 0.034 - ETA: 5s - loss: 4.6526 - acc: 0.033 - ETA: 5s - loss: 4.6512 - acc: 0.034 - ETA: 5s - loss: 4.6514 - acc: 0.034 - ETA: 4s - loss: 4.6452 - acc: 0.034 - ETA: 4s - loss: 4.6459 - acc: 0.033 - ETA: 4s - loss: 4.6479 - acc: 0.033 - ETA: 4s - loss: 4.6483 - acc: 0.033 - ETA: 4s - loss: 4.6457 - acc: 0.033 - ETA: 4s - loss: 4.6497 - acc: 0.033 - ETA: 4s - loss: 4.6511 - acc: 0.032 - ETA: 4s - loss: 4.6508 - acc: 0.033 - ETA: 4s - loss: 4.6502 - acc: 0.033 - ETA: 4s - loss: 4.6508 - acc: 0.033 - ETA: 4s - loss: 4.6471 - acc: 0.034 - ETA: 4s - loss: 4.6469 - acc: 0.034 - ETA: 4s - loss: 4.6465 - acc: 0.034 - ETA: 4s - loss: 4.6461 - acc: 0.034 - ETA: 4s - loss: 4.6495 - acc: 0.034 - ETA: 3s - loss: 4.6505 - acc: 0.034 - ETA: 3s - loss: 4.6528 - acc: 0.033 - ETA: 3s - loss: 4.6505 - acc: 0.033 - ETA: 3s - loss: 4.6498 - acc: 0.033 - ETA: 3s - loss: 4.6480 - acc: 0.034 - ETA: 3s - loss: 4.6480 - acc: 0.034 - ETA: 3s - loss: 4.6461 - acc: 0.033 - ETA: 3s - loss: 4.6456 - acc: 0.033 - ETA: 3s - loss: 4.6452 - acc: 0.033 - ETA: 3s - loss: 4.6453 - acc: 0.033 - ETA: 3s - loss: 4.6465 - acc: 0.033 - ETA: 3s - loss: 4.6486 - acc: 0.032 - ETA: 3s - loss: 4.6474 - acc: 0.033 - ETA: 3s - loss: 4.6450 - acc: 0.033 - ETA: 3s - loss: 4.6436 - acc: 0.033 - ETA: 2s - loss: 4.6434 - acc: 0.033 - ETA: 2s - loss: 4.6408 - acc: 0.033 - ETA: 2s - loss: 4.6404 - acc: 0.033 - ETA: 2s - loss: 4.6402 - acc: 0.033 - ETA: 2s - loss: 4.6369 - acc: 0.033 - ETA: 2s - loss: 4.6347 - acc: 0.034 - ETA: 2s - loss: 4.6351 - acc: 0.034 - ETA: 2s - loss: 4.6360 - acc: 0.034 - ETA: 2s - loss: 4.6335 - acc: 0.034 - ETA: 2s - loss: 4.6334 - acc: 0.034 - ETA: 2s - loss: 4.6330 - acc: 0.034 - ETA: 2s - loss: 4.6312 - acc: 0.034 - ETA: 2s - loss: 4.6299 - acc: 0.035 - ETA: 2s - loss: 4.6297 - acc: 0.034 - ETA: 2s - loss: 4.6281 - acc: 0.034 - ETA: 2s - loss: 4.6278 - acc: 0.034 - ETA: 1s - loss: 4.6307 - acc: 0.034 - ETA: 1s - loss: 4.6291 - acc: 0.034 - ETA: 1s - loss: 4.6287 - acc: 0.034 - ETA: 1s - loss: 4.6289 - acc: 0.034 - ETA: 1s - loss: 4.6303 - acc: 0.034 - ETA: 1s - loss: 4.6289 - acc: 0.034 - ETA: 1s - loss: 4.6280 - acc: 0.034 - ETA: 1s - loss: 4.6291 - acc: 0.034 - ETA: 1s - loss: 4.6282 - acc: 0.034 - ETA: 1s - loss: 4.6274 - acc: 0.034 - ETA: 1s - loss: 4.6258 - acc: 0.034 - ETA: 1s - loss: 4.6259 - acc: 0.035 - ETA: 1s - loss: 4.6267 - acc: 0.035 - ETA: 1s - loss: 4.6258 - acc: 0.035 - ETA: 1s - loss: 4.6251 - acc: 0.035 - ETA: 0s - loss: 4.6248 - acc: 0.035 - ETA: 0s - loss: 4.6243 - acc: 0.035 - ETA: 0s - loss: 4.6246 - acc: 0.035 - ETA: 0s - loss: 4.6232 - acc: 0.035 - ETA: 0s - loss: 4.6227 - acc: 0.035 - ETA: 0s - loss: 4.6227 - acc: 0.034 - ETA: 0s - loss: 4.6230 - acc: 0.034 - ETA: 0s - loss: 4.6233 - acc: 0.0 ...
# 6680/6680 [==============================] - 7s - loss: 4.6205 - acc: 0.0349 - val_loss: 4.5937 - val_acc: 0.0359
# Epoch 3/10
# 6660/6680 [============================>.] - ETA: 6s - loss: 4.4951 - acc: 0.0000e+0 - ETA: 7s - loss: 4.5242 - acc: 0.0375    - ETA: 7s - loss: 4.5688 - acc: 0.042 - ETA: 6s - loss: 4.5699 - acc: 0.035 - ETA: 6s - loss: 4.5556 - acc: 0.050 - ETA: 6s - loss: 4.5313 - acc: 0.050 - ETA: 6s - loss: 4.5369 - acc: 0.047 - ETA: 6s - loss: 4.5394 - acc: 0.043 - ETA: 6s - loss: 4.5506 - acc: 0.042 - ETA: 6s - loss: 4.5412 - acc: 0.044 - ETA: 6s - loss: 4.5367 - acc: 0.048 - ETA: 6s - loss: 4.5344 - acc: 0.048 - ETA: 6s - loss: 4.5333 - acc: 0.045 - ETA: 6s - loss: 4.5430 - acc: 0.045 - ETA: 6s - loss: 4.5466 - acc: 0.046 - ETA: 6s - loss: 4.5529 - acc: 0.047 - ETA: 6s - loss: 4.5528 - acc: 0.049 - ETA: 6s - loss: 4.5594 - acc: 0.048 - ETA: 6s - loss: 4.5496 - acc: 0.049 - ETA: 5s - loss: 4.5476 - acc: 0.047 - ETA: 5s - loss: 4.5499 - acc: 0.045 - ETA: 5s - loss: 4.5515 - acc: 0.046 - ETA: 5s - loss: 4.5584 - acc: 0.044 - ETA: 5s - loss: 4.5589 - acc: 0.043 - ETA: 5s - loss: 4.5638 - acc: 0.044 - ETA: 5s - loss: 4.5588 - acc: 0.043 - ETA: 5s - loss: 4.5534 - acc: 0.043 - ETA: 5s - loss: 4.5497 - acc: 0.042 - ETA: 5s - loss: 4.5514 - acc: 0.044 - ETA: 5s - loss: 4.5444 - acc: 0.044 - ETA: 5s - loss: 4.5373 - acc: 0.046 - ETA: 5s - loss: 4.5386 - acc: 0.045 - ETA: 5s - loss: 4.5355 - acc: 0.044 - ETA: 5s - loss: 4.5348 - acc: 0.044 - ETA: 4s - loss: 4.5385 - acc: 0.043 - ETA: 4s - loss: 4.5390 - acc: 0.043 - ETA: 4s - loss: 4.5413 - acc: 0.042 - ETA: 4s - loss: 4.5385 - acc: 0.042 - ETA: 4s - loss: 4.5397 - acc: 0.043 - ETA: 4s - loss: 4.5403 - acc: 0.042 - ETA: 4s - loss: 4.5395 - acc: 0.042 - ETA: 4s - loss: 4.5343 - acc: 0.043 - ETA: 4s - loss: 4.5303 - acc: 0.043 - ETA: 4s - loss: 4.5330 - acc: 0.043 - ETA: 4s - loss: 4.5333 - acc: 0.043 - ETA: 4s - loss: 4.5340 - acc: 0.042 - ETA: 4s - loss: 4.5343 - acc: 0.043 - ETA: 4s - loss: 4.5324 - acc: 0.044 - ETA: 4s - loss: 4.5299 - acc: 0.044 - ETA: 4s - loss: 4.5307 - acc: 0.044 - ETA: 3s - loss: 4.5276 - acc: 0.044 - ETA: 3s - loss: 4.5291 - acc: 0.045 - ETA: 3s - loss: 4.5271 - acc: 0.044 - ETA: 3s - loss: 4.5271 - acc: 0.044 - ETA: 3s - loss: 4.5246 - acc: 0.045 - ETA: 3s - loss: 4.5251 - acc: 0.045 - ETA: 3s - loss: 4.5300 - acc: 0.044 - ETA: 3s - loss: 4.5276 - acc: 0.044 - ETA: 3s - loss: 4.5301 - acc: 0.045 - ETA: 3s - loss: 4.5303 - acc: 0.045 - ETA: 3s - loss: 4.5293 - acc: 0.045 - ETA: 3s - loss: 4.5287 - acc: 0.045 - ETA: 3s - loss: 4.5275 - acc: 0.045 - ETA: 3s - loss: 4.5271 - acc: 0.045 - ETA: 3s - loss: 4.5269 - acc: 0.045 - ETA: 2s - loss: 4.5273 - acc: 0.045 - ETA: 2s - loss: 4.5254 - acc: 0.045 - ETA: 2s - loss: 4.5260 - acc: 0.045 - ETA: 2s - loss: 4.5268 - acc: 0.044 - ETA: 2s - loss: 4.5242 - acc: 0.045 - ETA: 2s - loss: 4.5240 - acc: 0.045 - ETA: 2s - loss: 4.5265 - acc: 0.044 - ETA: 2s - loss: 4.5282 - acc: 0.044 - ETA: 2s - loss: 4.5260 - acc: 0.045 - ETA: 2s - loss: 4.5260 - acc: 0.045 - ETA: 2s - loss: 4.5266 - acc: 0.044 - ETA: 2s - loss: 4.5261 - acc: 0.045 - ETA: 2s - loss: 4.5273 - acc: 0.044 - ETA: 2s - loss: 4.5281 - acc: 0.044 - ETA: 2s - loss: 4.5284 - acc: 0.044 - ETA: 2s - loss: 4.5268 - acc: 0.044 - ETA: 1s - loss: 4.5277 - acc: 0.044 - ETA: 1s - loss: 4.5288 - acc: 0.044 - ETA: 1s - loss: 4.5288 - acc: 0.044 - ETA: 1s - loss: 4.5289 - acc: 0.043 - ETA: 1s - loss: 4.5284 - acc: 0.044 - ETA: 1s - loss: 4.5299 - acc: 0.044 - ETA: 1s - loss: 4.5297 - acc: 0.044 - ETA: 1s - loss: 4.5293 - acc: 0.044 - ETA: 1s - loss: 4.5293 - acc: 0.044 - ETA: 1s - loss: 4.5282 - acc: 0.044 - ETA: 1s - loss: 4.5272 - acc: 0.045 - ETA: 1s - loss: 4.5278 - acc: 0.045 - ETA: 1s - loss: 4.5288 - acc: 0.045 - ETA: 1s - loss: 4.5280 - acc: 0.045 - ETA: 1s - loss: 4.5257 - acc: 0.045 - ETA: 0s - loss: 4.5238 - acc: 0.045 - ETA: 0s - loss: 4.5250 - acc: 0.045 - ETA: 0s - loss: 4.5255 - acc: 0.044 - ETA: 0s - loss: 4.5242 - acc: 0.045 - ETA: 0s - loss: 4.5262 - acc: 0.044 - ETA: 0s - loss: 4.5251 - acc: 0.045 - ETA: 0s - loss: 4.5249 - acc: 0.045 - ETA: 0s - loss: 4.5226 - acc: 0.0 ...
# 6680/6680 [==============================] - 7s - loss: 4.5243 - acc: 0.0449 - val_loss: 4.5576 - val_acc: 0.0419
# Epoch 4/10
# 6660/6680 [============================>.] - ETA: 6s - loss: 4.5501 - acc: 0.0000e+0 - ETA: 7s - loss: 4.5078 - acc: 0.0625    - ETA: 7s - loss: 4.4476 - acc: 0.071 - ETA: 7s - loss: 4.4302 - acc: 0.065 - ETA: 7s - loss: 4.4391 - acc: 0.061 - ETA: 7s - loss: 4.4591 - acc: 0.062 - ETA: 7s - loss: 4.4641 - acc: 0.055 - ETA: 7s - loss: 4.4655 - acc: 0.054 - ETA: 6s - loss: 4.4844 - acc: 0.052 - ETA: 6s - loss: 4.4853 - acc: 0.046 - ETA: 6s - loss: 4.4829 - acc: 0.046 - ETA: 6s - loss: 4.4682 - acc: 0.051 - ETA: 6s - loss: 4.4640 - acc: 0.056 - ETA: 6s - loss: 4.4544 - acc: 0.058 - ETA: 6s - loss: 4.4556 - acc: 0.059 - ETA: 6s - loss: 4.4497 - acc: 0.058 - ETA: 6s - loss: 4.4562 - acc: 0.057 - ETA: 6s - loss: 4.4670 - acc: 0.054 - ETA: 6s - loss: 4.4674 - acc: 0.054 - ETA: 6s - loss: 4.4704 - acc: 0.054 - ETA: 6s - loss: 4.4762 - acc: 0.054 - ETA: 5s - loss: 4.4703 - acc: 0.056 - ETA: 5s - loss: 4.4672 - acc: 0.057 - ETA: 5s - loss: 4.4657 - acc: 0.055 - ETA: 5s - loss: 4.4698 - acc: 0.054 - ETA: 5s - loss: 4.4748 - acc: 0.053 - ETA: 5s - loss: 4.4769 - acc: 0.054 - ETA: 5s - loss: 4.4871 - acc: 0.053 - ETA: 5s - loss: 4.4840 - acc: 0.054 - ETA: 5s - loss: 4.4838 - acc: 0.054 - ETA: 5s - loss: 4.4861 - acc: 0.053 - ETA: 5s - loss: 4.4829 - acc: 0.053 - ETA: 5s - loss: 4.4793 - acc: 0.053 - ETA: 5s - loss: 4.4768 - acc: 0.054 - ETA: 5s - loss: 4.4755 - acc: 0.053 - ETA: 4s - loss: 4.4742 - acc: 0.052 - ETA: 4s - loss: 4.4756 - acc: 0.052 - ETA: 4s - loss: 4.4771 - acc: 0.051 - ETA: 4s - loss: 4.4738 - acc: 0.052 - ETA: 4s - loss: 4.4682 - acc: 0.053 - ETA: 4s - loss: 4.4715 - acc: 0.052 - ETA: 4s - loss: 4.4719 - acc: 0.052 - ETA: 4s - loss: 4.4760 - acc: 0.052 - ETA: 4s - loss: 4.4749 - acc: 0.051 - ETA: 4s - loss: 4.4718 - acc: 0.051 - ETA: 4s - loss: 4.4661 - acc: 0.052 - ETA: 4s - loss: 4.4674 - acc: 0.052 - ETA: 4s - loss: 4.4648 - acc: 0.053 - ETA: 4s - loss: 4.4631 - acc: 0.055 - ETA: 4s - loss: 4.4650 - acc: 0.055 - ETA: 3s - loss: 4.4670 - acc: 0.055 - ETA: 3s - loss: 4.4668 - acc: 0.055 - ETA: 3s - loss: 4.4683 - acc: 0.055 - ETA: 3s - loss: 4.4651 - acc: 0.055 - ETA: 3s - loss: 4.4619 - acc: 0.056 - ETA: 3s - loss: 4.4599 - acc: 0.056 - ETA: 3s - loss: 4.4592 - acc: 0.055 - ETA: 3s - loss: 4.4589 - acc: 0.055 - ETA: 3s - loss: 4.4583 - acc: 0.055 - ETA: 3s - loss: 4.4592 - acc: 0.056 - ETA: 3s - loss: 4.4592 - acc: 0.055 - ETA: 3s - loss: 4.4596 - acc: 0.055 - ETA: 3s - loss: 4.4601 - acc: 0.055 - ETA: 3s - loss: 4.4611 - acc: 0.055 - ETA: 3s - loss: 4.4619 - acc: 0.055 - ETA: 2s - loss: 4.4599 - acc: 0.055 - ETA: 2s - loss: 4.4585 - acc: 0.055 - ETA: 2s - loss: 4.4589 - acc: 0.055 - ETA: 2s - loss: 4.4600 - acc: 0.055 - ETA: 2s - loss: 4.4586 - acc: 0.055 - ETA: 2s - loss: 4.4609 - acc: 0.055 - ETA: 2s - loss: 4.4606 - acc: 0.054 - ETA: 2s - loss: 4.4593 - acc: 0.055 - ETA: 2s - loss: 4.4592 - acc: 0.055 - ETA: 2s - loss: 4.4566 - acc: 0.056 - ETA: 2s - loss: 4.4577 - acc: 0.055 - ETA: 2s - loss: 4.4552 - acc: 0.056 - ETA: 2s - loss: 4.4568 - acc: 0.055 - ETA: 2s - loss: 4.4566 - acc: 0.055 - ETA: 2s - loss: 4.4568 - acc: 0.055 - ETA: 2s - loss: 4.4572 - acc: 0.056 - ETA: 1s - loss: 4.4589 - acc: 0.056 - ETA: 1s - loss: 4.4591 - acc: 0.056 - ETA: 1s - loss: 4.4599 - acc: 0.056 - ETA: 1s - loss: 4.4610 - acc: 0.055 - ETA: 1s - loss: 4.4609 - acc: 0.055 - ETA: 1s - loss: 4.4618 - acc: 0.056 - ETA: 1s - loss: 4.4608 - acc: 0.055 - ETA: 1s - loss: 4.4605 - acc: 0.055 - ETA: 1s - loss: 4.4614 - acc: 0.055 - ETA: 1s - loss: 4.4620 - acc: 0.055 - ETA: 1s - loss: 4.4619 - acc: 0.055 - ETA: 1s - loss: 4.4617 - acc: 0.055 - ETA: 1s - loss: 4.4614 - acc: 0.055 - ETA: 1s - loss: 4.4627 - acc: 0.055 - ETA: 1s - loss: 4.4634 - acc: 0.054 - ETA: 0s - loss: 4.4633 - acc: 0.054 - ETA: 0s - loss: 4.4631 - acc: 0.055 - ETA: 0s - loss: 4.4621 - acc: 0.055 - ETA: 0s - loss: 4.4626 - acc: 0.055 - ETA: 0s - loss: 4.4633 - acc: 0.055 - ETA: 0s - loss: 4.4624 - acc: 0.055 - ETA: 0s - loss: 4.4616 - acc: 0.055 - ETA: 0s - loss: 4.4624 - acc: 0.0 ...
# 6680/6680 [==============================] - 7s - loss: 4.4584 - acc: 0.0537 - val_loss: 4.4981 - val_acc: 0.0479
# Epoch 5/10
# 6640/6680 [============================>.] - ETA: 7s - loss: 4.5762 - acc: 0.050 - ETA: 7s - loss: 4.4821 - acc: 0.025 - ETA: 6s - loss: 4.5050 - acc: 0.028 - ETA: 6s - loss: 4.4511 - acc: 0.040 - ETA: 6s - loss: 4.4238 - acc: 0.030 - ETA: 6s - loss: 4.3958 - acc: 0.034 - ETA: 6s - loss: 4.3926 - acc: 0.042 - ETA: 6s - loss: 4.3659 - acc: 0.047 - ETA: 6s - loss: 4.3764 - acc: 0.046 - ETA: 6s - loss: 4.3669 - acc: 0.046 - ETA: 6s - loss: 4.3708 - acc: 0.045 - ETA: 6s - loss: 4.3715 - acc: 0.044 - ETA: 6s - loss: 4.3937 - acc: 0.045 - ETA: 6s - loss: 4.3852 - acc: 0.048 - ETA: 6s - loss: 4.3806 - acc: 0.050 - ETA: 6s - loss: 4.3772 - acc: 0.050 - ETA: 6s - loss: 4.3847 - acc: 0.048 - ETA: 6s - loss: 4.3778 - acc: 0.047 - ETA: 6s - loss: 4.3804 - acc: 0.049 - ETA: 5s - loss: 4.3898 - acc: 0.051 - ETA: 5s - loss: 4.3846 - acc: 0.054 - ETA: 5s - loss: 4.3809 - acc: 0.055 - ETA: 5s - loss: 4.3769 - acc: 0.059 - ETA: 5s - loss: 4.3848 - acc: 0.057 - ETA: 5s - loss: 4.3896 - acc: 0.057 - ETA: 5s - loss: 4.3900 - acc: 0.057 - ETA: 5s - loss: 4.3908 - acc: 0.058 - ETA: 5s - loss: 4.3926 - acc: 0.058 - ETA: 5s - loss: 4.3902 - acc: 0.059 - ETA: 5s - loss: 4.3879 - acc: 0.059 - ETA: 5s - loss: 4.3857 - acc: 0.058 - ETA: 5s - loss: 4.3903 - acc: 0.060 - ETA: 5s - loss: 4.3929 - acc: 0.060 - ETA: 5s - loss: 4.3874 - acc: 0.060 - ETA: 4s - loss: 4.3893 - acc: 0.060 - ETA: 4s - loss: 4.3869 - acc: 0.060 - ETA: 4s - loss: 4.3884 - acc: 0.058 - ETA: 4s - loss: 4.3870 - acc: 0.059 - ETA: 4s - loss: 4.3854 - acc: 0.059 - ETA: 4s - loss: 4.3917 - acc: 0.059 - ETA: 4s - loss: 4.3901 - acc: 0.059 - ETA: 4s - loss: 4.3902 - acc: 0.059 - ETA: 4s - loss: 4.3973 - acc: 0.058 - ETA: 4s - loss: 4.4014 - acc: 0.058 - ETA: 4s - loss: 4.4039 - acc: 0.058 - ETA: 4s - loss: 4.4075 - acc: 0.058 - ETA: 4s - loss: 4.4079 - acc: 0.057 - ETA: 4s - loss: 4.4071 - acc: 0.058 - ETA: 4s - loss: 4.4067 - acc: 0.058 - ETA: 4s - loss: 4.4060 - acc: 0.057 - ETA: 3s - loss: 4.4027 - acc: 0.056 - ETA: 3s - loss: 4.3985 - acc: 0.057 - ETA: 3s - loss: 4.3996 - acc: 0.056 - ETA: 3s - loss: 4.3992 - acc: 0.056 - ETA: 3s - loss: 4.3964 - acc: 0.056 - ETA: 3s - loss: 4.3965 - acc: 0.057 - ETA: 3s - loss: 4.3956 - acc: 0.057 - ETA: 3s - loss: 4.3929 - acc: 0.057 - ETA: 3s - loss: 4.3937 - acc: 0.057 - ETA: 3s - loss: 4.3928 - acc: 0.057 - ETA: 3s - loss: 4.3937 - acc: 0.056 - ETA: 3s - loss: 4.3943 - acc: 0.056 - ETA: 3s - loss: 4.3954 - acc: 0.056 - ETA: 3s - loss: 4.3959 - acc: 0.056 - ETA: 3s - loss: 4.3943 - acc: 0.056 - ETA: 3s - loss: 4.3919 - acc: 0.056 - ETA: 2s - loss: 4.3915 - acc: 0.056 - ETA: 2s - loss: 4.3922 - acc: 0.057 - ETA: 2s - loss: 4.3932 - acc: 0.057 - ETA: 2s - loss: 4.3956 - acc: 0.057 - ETA: 2s - loss: 4.3944 - acc: 0.057 - ETA: 2s - loss: 4.3966 - acc: 0.057 - ETA: 2s - loss: 4.3967 - acc: 0.056 - ETA: 2s - loss: 4.3981 - acc: 0.056 - ETA: 2s - loss: 4.3986 - acc: 0.055 - ETA: 2s - loss: 4.3992 - acc: 0.056 - ETA: 2s - loss: 4.3967 - acc: 0.056 - ETA: 2s - loss: 4.3955 - acc: 0.057 - ETA: 2s - loss: 4.3936 - acc: 0.056 - ETA: 2s - loss: 4.3982 - acc: 0.056 - ETA: 2s - loss: 4.3991 - acc: 0.056 - ETA: 1s - loss: 4.4002 - acc: 0.056 - ETA: 1s - loss: 4.4011 - acc: 0.056 - ETA: 1s - loss: 4.4004 - acc: 0.056 - ETA: 1s - loss: 4.4012 - acc: 0.056 - ETA: 1s - loss: 4.3980 - acc: 0.057 - ETA: 1s - loss: 4.3991 - acc: 0.057 - ETA: 1s - loss: 4.4004 - acc: 0.057 - ETA: 1s - loss: 4.3993 - acc: 0.057 - ETA: 1s - loss: 4.4020 - acc: 0.057 - ETA: 1s - loss: 4.4002 - acc: 0.056 - ETA: 1s - loss: 4.4013 - acc: 0.056 - ETA: 1s - loss: 4.4021 - acc: 0.056 - ETA: 1s - loss: 4.4009 - acc: 0.056 - ETA: 1s - loss: 4.4017 - acc: 0.056 - ETA: 1s - loss: 4.4007 - acc: 0.057 - ETA: 1s - loss: 4.4015 - acc: 0.056 - ETA: 0s - loss: 4.4021 - acc: 0.056 - ETA: 0s - loss: 4.4016 - acc: 0.056 - ETA: 0s - loss: 4.4004 - acc: 0.057 - ETA: 0s - loss: 4.4001 - acc: 0.057 - ETA: 0s - loss: 4.4008 - acc: 0.057 - ETA: 0s - loss: 4.3982 - acc: 0.057 - ETA: 0s - loss: 4.3973 - acc: 0.057 - ETA ...
# 6680/6680 [==============================] - 7s - loss: 4.4001 - acc: 0.0570 - val_loss: 4.4442 - val_acc: 0.0527
# Epoch 6/10
# 6640/6680 [============================>.] - ETA: 6s - loss: 4.3147 - acc: 0.0000e+0 - ETA: 7s - loss: 4.3772 - acc: 0.0625    - ETA: 7s - loss: 4.3050 - acc: 0.071 - ETA: 7s - loss: 4.3399 - acc: 0.075 - ETA: 7s - loss: 4.3256 - acc: 0.076 - ETA: 7s - loss: 4.3167 - acc: 0.068 - ETA: 6s - loss: 4.3356 - acc: 0.063 - ETA: 6s - loss: 4.3278 - acc: 0.065 - ETA: 6s - loss: 4.3181 - acc: 0.066 - ETA: 6s - loss: 4.3325 - acc: 0.064 - ETA: 6s - loss: 4.3390 - acc: 0.066 - ETA: 6s - loss: 4.3375 - acc: 0.067 - ETA: 6s - loss: 4.3481 - acc: 0.063 - ETA: 6s - loss: 4.3476 - acc: 0.066 - ETA: 6s - loss: 4.3480 - acc: 0.070 - ETA: 6s - loss: 4.3535 - acc: 0.071 - ETA: 6s - loss: 4.3456 - acc: 0.071 - ETA: 6s - loss: 4.3484 - acc: 0.070 - ETA: 6s - loss: 4.3546 - acc: 0.072 - ETA: 5s - loss: 4.3475 - acc: 0.075 - ETA: 5s - loss: 4.3576 - acc: 0.072 - ETA: 5s - loss: 4.3563 - acc: 0.071 - ETA: 5s - loss: 4.3475 - acc: 0.073 - ETA: 5s - loss: 4.3571 - acc: 0.070 - ETA: 5s - loss: 4.3511 - acc: 0.071 - ETA: 5s - loss: 4.3634 - acc: 0.070 - ETA: 5s - loss: 4.3710 - acc: 0.067 - ETA: 5s - loss: 4.3682 - acc: 0.067 - ETA: 5s - loss: 4.3646 - acc: 0.069 - ETA: 5s - loss: 4.3656 - acc: 0.068 - ETA: 5s - loss: 4.3676 - acc: 0.068 - ETA: 5s - loss: 4.3607 - acc: 0.067 - ETA: 5s - loss: 4.3640 - acc: 0.067 - ETA: 5s - loss: 4.3606 - acc: 0.067 - ETA: 4s - loss: 4.3617 - acc: 0.068 - ETA: 4s - loss: 4.3686 - acc: 0.067 - ETA: 4s - loss: 4.3696 - acc: 0.066 - ETA: 4s - loss: 4.3724 - acc: 0.064 - ETA: 4s - loss: 4.3731 - acc: 0.064 - ETA: 4s - loss: 4.3757 - acc: 0.064 - ETA: 4s - loss: 4.3759 - acc: 0.063 - ETA: 4s - loss: 4.3747 - acc: 0.063 - ETA: 4s - loss: 4.3731 - acc: 0.064 - ETA: 4s - loss: 4.3736 - acc: 0.065 - ETA: 4s - loss: 4.3780 - acc: 0.064 - ETA: 4s - loss: 4.3819 - acc: 0.063 - ETA: 4s - loss: 4.3800 - acc: 0.063 - ETA: 4s - loss: 4.3790 - acc: 0.063 - ETA: 4s - loss: 4.3761 - acc: 0.063 - ETA: 4s - loss: 4.3747 - acc: 0.064 - ETA: 3s - loss: 4.3766 - acc: 0.063 - ETA: 3s - loss: 4.3761 - acc: 0.063 - ETA: 3s - loss: 4.3731 - acc: 0.063 - ETA: 3s - loss: 4.3697 - acc: 0.063 - ETA: 3s - loss: 4.3658 - acc: 0.063 - ETA: 3s - loss: 4.3643 - acc: 0.063 - ETA: 3s - loss: 4.3625 - acc: 0.063 - ETA: 3s - loss: 4.3632 - acc: 0.062 - ETA: 3s - loss: 4.3614 - acc: 0.062 - ETA: 3s - loss: 4.3588 - acc: 0.063 - ETA: 3s - loss: 4.3599 - acc: 0.063 - ETA: 3s - loss: 4.3599 - acc: 0.062 - ETA: 3s - loss: 4.3605 - acc: 0.062 - ETA: 3s - loss: 4.3612 - acc: 0.062 - ETA: 3s - loss: 4.3647 - acc: 0.062 - ETA: 2s - loss: 4.3657 - acc: 0.061 - ETA: 2s - loss: 4.3648 - acc: 0.062 - ETA: 2s - loss: 4.3634 - acc: 0.062 - ETA: 2s - loss: 4.3626 - acc: 0.062 - ETA: 2s - loss: 4.3653 - acc: 0.062 - ETA: 2s - loss: 4.3610 - acc: 0.062 - ETA: 2s - loss: 4.3593 - acc: 0.062 - ETA: 2s - loss: 4.3578 - acc: 0.063 - ETA: 2s - loss: 4.3608 - acc: 0.063 - ETA: 2s - loss: 4.3621 - acc: 0.062 - ETA: 2s - loss: 4.3620 - acc: 0.062 - ETA: 2s - loss: 4.3617 - acc: 0.062 - ETA: 2s - loss: 4.3620 - acc: 0.062 - ETA: 2s - loss: 4.3603 - acc: 0.063 - ETA: 2s - loss: 4.3582 - acc: 0.063 - ETA: 2s - loss: 4.3565 - acc: 0.062 - ETA: 1s - loss: 4.3551 - acc: 0.062 - ETA: 1s - loss: 4.3543 - acc: 0.062 - ETA: 1s - loss: 4.3556 - acc: 0.062 - ETA: 1s - loss: 4.3577 - acc: 0.061 - ETA: 1s - loss: 4.3573 - acc: 0.061 - ETA: 1s - loss: 4.3558 - acc: 0.061 - ETA: 1s - loss: 4.3575 - acc: 0.061 - ETA: 1s - loss: 4.3610 - acc: 0.060 - ETA: 1s - loss: 4.3592 - acc: 0.060 - ETA: 1s - loss: 4.3609 - acc: 0.060 - ETA: 1s - loss: 4.3600 - acc: 0.060 - ETA: 1s - loss: 4.3576 - acc: 0.061 - ETA: 1s - loss: 4.3581 - acc: 0.061 - ETA: 1s - loss: 4.3587 - acc: 0.061 - ETA: 1s - loss: 4.3578 - acc: 0.061 - ETA: 1s - loss: 4.3575 - acc: 0.061 - ETA: 0s - loss: 4.3577 - acc: 0.061 - ETA: 0s - loss: 4.3573 - acc: 0.061 - ETA: 0s - loss: 4.3579 - acc: 0.061 - ETA: 0s - loss: 4.3557 - acc: 0.061 - ETA: 0s - loss: 4.3564 - acc: 0.061 - ETA: 0s - loss: 4.3571 - acc: 0.061 - ETA: 0s - loss: 4.3574 - acc: 0.0 ...
# 6680/6680 [==============================] - 7s - loss: 4.3526 - acc: 0.0624 - val_loss: 4.3972 - val_acc: 0.0575
# Epoch 7/10
# 6660/6680 [============================>.] - ETA: 6s - loss: 4.1323 - acc: 0.0000e+0 - ETA: 7s - loss: 4.2353 - acc: 0.0000e+0 - ETA: 7s - loss: 4.1644 - acc: 0.0357    - ETA: 6s - loss: 4.1802 - acc: 0.050 - ETA: 6s - loss: 4.2383 - acc: 0.065 - ETA: 6s - loss: 4.2404 - acc: 0.068 - ETA: 6s - loss: 4.2588 - acc: 0.071 - ETA: 6s - loss: 4.2847 - acc: 0.070 - ETA: 6s - loss: 4.2708 - acc: 0.068 - ETA: 6s - loss: 4.2856 - acc: 0.067 - ETA: 6s - loss: 4.2814 - acc: 0.067 - ETA: 6s - loss: 4.2841 - acc: 0.066 - ETA: 6s - loss: 4.2967 - acc: 0.064 - ETA: 6s - loss: 4.3067 - acc: 0.061 - ETA: 6s - loss: 4.2874 - acc: 0.064 - ETA: 6s - loss: 4.2748 - acc: 0.065 - ETA: 6s - loss: 4.2779 - acc: 0.062 - ETA: 6s - loss: 4.2753 - acc: 0.063 - ETA: 6s - loss: 4.2775 - acc: 0.062 - ETA: 5s - loss: 4.2730 - acc: 0.064 - ETA: 5s - loss: 4.2759 - acc: 0.066 - ETA: 5s - loss: 4.2780 - acc: 0.064 - ETA: 5s - loss: 4.2797 - acc: 0.064 - ETA: 5s - loss: 4.2816 - acc: 0.063 - ETA: 5s - loss: 4.2787 - acc: 0.066 - ETA: 5s - loss: 4.2789 - acc: 0.064 - ETA: 5s - loss: 4.2788 - acc: 0.066 - ETA: 5s - loss: 4.2783 - acc: 0.066 - ETA: 5s - loss: 4.2843 - acc: 0.066 - ETA: 5s - loss: 4.2801 - acc: 0.066 - ETA: 5s - loss: 4.2852 - acc: 0.066 - ETA: 5s - loss: 4.2847 - acc: 0.066 - ETA: 5s - loss: 4.2768 - acc: 0.069 - ETA: 5s - loss: 4.2861 - acc: 0.069 - ETA: 5s - loss: 4.2883 - acc: 0.070 - ETA: 4s - loss: 4.2893 - acc: 0.070 - ETA: 4s - loss: 4.2931 - acc: 0.069 - ETA: 4s - loss: 4.2893 - acc: 0.070 - ETA: 4s - loss: 4.2886 - acc: 0.069 - ETA: 4s - loss: 4.2905 - acc: 0.069 - ETA: 4s - loss: 4.2952 - acc: 0.069 - ETA: 4s - loss: 4.2906 - acc: 0.070 - ETA: 4s - loss: 4.2888 - acc: 0.070 - ETA: 4s - loss: 4.2870 - acc: 0.070 - ETA: 4s - loss: 4.2853 - acc: 0.070 - ETA: 4s - loss: 4.2863 - acc: 0.070 - ETA: 4s - loss: 4.2854 - acc: 0.070 - ETA: 4s - loss: 4.2842 - acc: 0.072 - ETA: 4s - loss: 4.2828 - acc: 0.072 - ETA: 4s - loss: 4.2869 - acc: 0.071 - ETA: 3s - loss: 4.2873 - acc: 0.070 - ETA: 3s - loss: 4.2865 - acc: 0.069 - ETA: 3s - loss: 4.2876 - acc: 0.070 - ETA: 3s - loss: 4.2876 - acc: 0.071 - ETA: 3s - loss: 4.2916 - acc: 0.071 - ETA: 3s - loss: 4.2946 - acc: 0.070 - ETA: 3s - loss: 4.2934 - acc: 0.070 - ETA: 3s - loss: 4.2942 - acc: 0.069 - ETA: 3s - loss: 4.2916 - acc: 0.070 - ETA: 3s - loss: 4.2914 - acc: 0.070 - ETA: 3s - loss: 4.2878 - acc: 0.070 - ETA: 3s - loss: 4.2868 - acc: 0.070 - ETA: 3s - loss: 4.2874 - acc: 0.070 - ETA: 3s - loss: 4.2864 - acc: 0.070 - ETA: 3s - loss: 4.2874 - acc: 0.070 - ETA: 2s - loss: 4.2885 - acc: 0.070 - ETA: 2s - loss: 4.2893 - acc: 0.070 - ETA: 2s - loss: 4.2910 - acc: 0.070 - ETA: 2s - loss: 4.2916 - acc: 0.069 - ETA: 2s - loss: 4.2922 - acc: 0.069 - ETA: 2s - loss: 4.2894 - acc: 0.070 - ETA: 2s - loss: 4.2916 - acc: 0.069 - ETA: 2s - loss: 4.2911 - acc: 0.069 - ETA: 2s - loss: 4.2911 - acc: 0.069 - ETA: 2s - loss: 4.2943 - acc: 0.068 - ETA: 2s - loss: 4.2947 - acc: 0.068 - ETA: 2s - loss: 4.2924 - acc: 0.069 - ETA: 2s - loss: 4.2931 - acc: 0.069 - ETA: 2s - loss: 4.2923 - acc: 0.068 - ETA: 2s - loss: 4.2945 - acc: 0.068 - ETA: 2s - loss: 4.2942 - acc: 0.068 - ETA: 1s - loss: 4.2962 - acc: 0.067 - ETA: 1s - loss: 4.2967 - acc: 0.067 - ETA: 1s - loss: 4.2969 - acc: 0.067 - ETA: 1s - loss: 4.2968 - acc: 0.067 - ETA: 1s - loss: 4.2985 - acc: 0.067 - ETA: 1s - loss: 4.2986 - acc: 0.067 - ETA: 1s - loss: 4.3011 - acc: 0.067 - ETA: 1s - loss: 4.3010 - acc: 0.067 - ETA: 1s - loss: 4.3031 - acc: 0.067 - ETA: 1s - loss: 4.3006 - acc: 0.067 - ETA: 1s - loss: 4.3024 - acc: 0.067 - ETA: 1s - loss: 4.3013 - acc: 0.067 - ETA: 1s - loss: 4.2981 - acc: 0.067 - ETA: 1s - loss: 4.2966 - acc: 0.068 - ETA: 1s - loss: 4.2951 - acc: 0.068 - ETA: 0s - loss: 4.2957 - acc: 0.068 - ETA: 0s - loss: 4.2973 - acc: 0.067 - ETA: 0s - loss: 4.2985 - acc: 0.067 - ETA: 0s - loss: 4.2992 - acc: 0.067 - ETA: 0s - loss: 4.2968 - acc: 0.068 - ETA: 0s - loss: 4.2959 - acc: 0.068 - ETA: 0s - loss: 4.2948 - acc: 0.068 - ETA: 0s - loss: 4.2942 - acc: ...
# 6680/6680 [==============================] - 7s - loss: 4.2977 - acc: 0.0686 - val_loss: 4.3731 - val_acc: 0.0563
# Epoch 8/10
# 6620/6680 [============================>.] - ETA: 6s - loss: 4.0644 - acc: 0.150 - ETA: 7s - loss: 4.1447 - acc: 0.100 - ETA: 7s - loss: 4.0801 - acc: 0.135 - ETA: 7s - loss: 4.1442 - acc: 0.125 - ETA: 7s - loss: 4.1825 - acc: 0.123 - ETA: 6s - loss: 4.2022 - acc: 0.125 - ETA: 6s - loss: 4.1809 - acc: 0.121 - ETA: 6s - loss: 4.1760 - acc: 0.111 - ETA: 6s - loss: 4.1866 - acc: 0.104 - ETA: 6s - loss: 4.1936 - acc: 0.096 - ETA: 6s - loss: 4.2122 - acc: 0.091 - ETA: 6s - loss: 4.2141 - acc: 0.092 - ETA: 6s - loss: 4.1987 - acc: 0.097 - ETA: 6s - loss: 4.2049 - acc: 0.092 - ETA: 6s - loss: 4.2014 - acc: 0.091 - ETA: 6s - loss: 4.2060 - acc: 0.090 - ETA: 6s - loss: 4.2143 - acc: 0.087 - ETA: 6s - loss: 4.2137 - acc: 0.084 - ETA: 5s - loss: 4.2170 - acc: 0.081 - ETA: 5s - loss: 4.2204 - acc: 0.080 - ETA: 5s - loss: 4.2222 - acc: 0.081 - ETA: 5s - loss: 4.2253 - acc: 0.077 - ETA: 5s - loss: 4.2295 - acc: 0.079 - ETA: 5s - loss: 4.2340 - acc: 0.077 - ETA: 5s - loss: 4.2326 - acc: 0.078 - ETA: 5s - loss: 4.2430 - acc: 0.076 - ETA: 5s - loss: 4.2453 - acc: 0.074 - ETA: 5s - loss: 4.2582 - acc: 0.074 - ETA: 5s - loss: 4.2574 - acc: 0.073 - ETA: 5s - loss: 4.2665 - acc: 0.073 - ETA: 5s - loss: 4.2634 - acc: 0.073 - ETA: 5s - loss: 4.2639 - acc: 0.073 - ETA: 5s - loss: 4.2641 - acc: 0.073 - ETA: 5s - loss: 4.2664 - acc: 0.072 - ETA: 4s - loss: 4.2650 - acc: 0.070 - ETA: 4s - loss: 4.2611 - acc: 0.070 - ETA: 4s - loss: 4.2627 - acc: 0.070 - ETA: 4s - loss: 4.2587 - acc: 0.069 - ETA: 4s - loss: 4.2591 - acc: 0.070 - ETA: 4s - loss: 4.2609 - acc: 0.070 - ETA: 4s - loss: 4.2624 - acc: 0.070 - ETA: 4s - loss: 4.2581 - acc: 0.071 - ETA: 4s - loss: 4.2608 - acc: 0.071 - ETA: 4s - loss: 4.2560 - acc: 0.073 - ETA: 4s - loss: 4.2561 - acc: 0.072 - ETA: 4s - loss: 4.2608 - acc: 0.074 - ETA: 4s - loss: 4.2630 - acc: 0.075 - ETA: 4s - loss: 4.2631 - acc: 0.074 - ETA: 4s - loss: 4.2602 - acc: 0.074 - ETA: 4s - loss: 4.2589 - acc: 0.073 - ETA: 3s - loss: 4.2587 - acc: 0.073 - ETA: 3s - loss: 4.2571 - acc: 0.074 - ETA: 3s - loss: 4.2559 - acc: 0.074 - ETA: 3s - loss: 4.2520 - acc: 0.077 - ETA: 3s - loss: 4.2529 - acc: 0.077 - ETA: 3s - loss: 4.2554 - acc: 0.077 - ETA: 3s - loss: 4.2578 - acc: 0.076 - ETA: 3s - loss: 4.2603 - acc: 0.075 - ETA: 3s - loss: 4.2605 - acc: 0.075 - ETA: 3s - loss: 4.2607 - acc: 0.076 - ETA: 3s - loss: 4.2598 - acc: 0.076 - ETA: 3s - loss: 4.2577 - acc: 0.076 - ETA: 3s - loss: 4.2520 - acc: 0.077 - ETA: 3s - loss: 4.2509 - acc: 0.077 - ETA: 3s - loss: 4.2514 - acc: 0.076 - ETA: 3s - loss: 4.2536 - acc: 0.076 - ETA: 2s - loss: 4.2551 - acc: 0.075 - ETA: 2s - loss: 4.2552 - acc: 0.075 - ETA: 2s - loss: 4.2539 - acc: 0.075 - ETA: 2s - loss: 4.2522 - acc: 0.075 - ETA: 2s - loss: 4.2507 - acc: 0.076 - ETA: 2s - loss: 4.2505 - acc: 0.076 - ETA: 2s - loss: 4.2511 - acc: 0.075 - ETA: 2s - loss: 4.2542 - acc: 0.075 - ETA: 2s - loss: 4.2547 - acc: 0.075 - ETA: 2s - loss: 4.2529 - acc: 0.076 - ETA: 2s - loss: 4.2556 - acc: 0.075 - ETA: 2s - loss: 4.2557 - acc: 0.075 - ETA: 2s - loss: 4.2542 - acc: 0.075 - ETA: 2s - loss: 4.2568 - acc: 0.075 - ETA: 2s - loss: 4.2556 - acc: 0.076 - ETA: 1s - loss: 4.2536 - acc: 0.077 - ETA: 1s - loss: 4.2526 - acc: 0.077 - ETA: 1s - loss: 4.2536 - acc: 0.076 - ETA: 1s - loss: 4.2546 - acc: 0.076 - ETA: 1s - loss: 4.2552 - acc: 0.076 - ETA: 1s - loss: 4.2514 - acc: 0.077 - ETA: 1s - loss: 4.2534 - acc: 0.076 - ETA: 1s - loss: 4.2530 - acc: 0.076 - ETA: 1s - loss: 4.2536 - acc: 0.077 - ETA: 1s - loss: 4.2530 - acc: 0.077 - ETA: 1s - loss: 4.2560 - acc: 0.077 - ETA: 1s - loss: 4.2560 - acc: 0.077 - ETA: 1s - loss: 4.2549 - acc: 0.077 - ETA: 1s - loss: 4.2533 - acc: 0.078 - ETA: 1s - loss: 4.2518 - acc: 0.078 - ETA: 0s - loss: 4.2529 - acc: 0.078 - ETA: 0s - loss: 4.2527 - acc: 0.077 - ETA: 0s - loss: 4.2555 - acc: 0.077 - ETA: 0s - loss: 4.2571 - acc: 0.077 - ETA: 0s - loss: 4.2561 - acc: 0.076 - ETA: 0s - loss: 4.2564 - acc: 0.077 - ETA: 0s - loss: 4.2545 - acc: 0.077 - ETA: 0s - loss: 4.2519 - acc: 0.077 - ETA ...
# 6680/6680 [==============================] - 7s - loss: 4.2531 - acc: 0.0781 - val_loss: 4.3742 - val_acc: 0.0599
# Epoch 9/10
# 6620/6680 [============================>.] - ETA: 9s - loss: 4.1844 - acc: 0.100 - ETA: 7s - loss: 4.2228 - acc: 0.062 - ETA: 7s - loss: 4.0696 - acc: 0.078 - ETA: 7s - loss: 4.0717 - acc: 0.080 - ETA: 7s - loss: 4.0934 - acc: 0.080 - ETA: 7s - loss: 4.1288 - acc: 0.073 - ETA: 7s - loss: 4.1294 - acc: 0.080 - ETA: 6s - loss: 4.1192 - acc: 0.085 - ETA: 7s - loss: 4.1049 - acc: 0.084 - ETA: 7s - loss: 4.1044 - acc: 0.086 - ETA: 6s - loss: 4.0980 - acc: 0.087 - ETA: 6s - loss: 4.1003 - acc: 0.090 - ETA: 6s - loss: 4.1031 - acc: 0.092 - ETA: 6s - loss: 4.1115 - acc: 0.091 - ETA: 6s - loss: 4.1185 - acc: 0.088 - ETA: 6s - loss: 4.1153 - acc: 0.089 - ETA: 6s - loss: 4.1033 - acc: 0.094 - ETA: 6s - loss: 4.1251 - acc: 0.091 - ETA: 6s - loss: 4.1327 - acc: 0.089 - ETA: 6s - loss: 4.1328 - acc: 0.089 - ETA: 6s - loss: 4.1407 - acc: 0.087 - ETA: 6s - loss: 4.1392 - acc: 0.089 - ETA: 6s - loss: 4.1399 - acc: 0.089 - ETA: 5s - loss: 4.1463 - acc: 0.087 - ETA: 5s - loss: 4.1437 - acc: 0.088 - ETA: 5s - loss: 4.1546 - acc: 0.086 - ETA: 5s - loss: 4.1546 - acc: 0.084 - ETA: 5s - loss: 4.1499 - acc: 0.086 - ETA: 5s - loss: 4.1447 - acc: 0.087 - ETA: 5s - loss: 4.1528 - acc: 0.087 - ETA: 5s - loss: 4.1549 - acc: 0.087 - ETA: 5s - loss: 4.1537 - acc: 0.087 - ETA: 5s - loss: 4.1582 - acc: 0.087 - ETA: 5s - loss: 4.1551 - acc: 0.088 - ETA: 5s - loss: 4.1501 - acc: 0.090 - ETA: 5s - loss: 4.1510 - acc: 0.090 - ETA: 5s - loss: 4.1513 - acc: 0.090 - ETA: 4s - loss: 4.1483 - acc: 0.092 - ETA: 4s - loss: 4.1531 - acc: 0.091 - ETA: 4s - loss: 4.1574 - acc: 0.089 - ETA: 4s - loss: 4.1612 - acc: 0.089 - ETA: 4s - loss: 4.1633 - acc: 0.088 - ETA: 4s - loss: 4.1596 - acc: 0.089 - ETA: 4s - loss: 4.1583 - acc: 0.090 - ETA: 4s - loss: 4.1619 - acc: 0.091 - ETA: 4s - loss: 4.1582 - acc: 0.092 - ETA: 4s - loss: 4.1581 - acc: 0.092 - ETA: 4s - loss: 4.1582 - acc: 0.091 - ETA: 4s - loss: 4.1591 - acc: 0.090 - ETA: 4s - loss: 4.1583 - acc: 0.090 - ETA: 4s - loss: 4.1603 - acc: 0.090 - ETA: 4s - loss: 4.1600 - acc: 0.090 - ETA: 4s - loss: 4.1609 - acc: 0.091 - ETA: 3s - loss: 4.1607 - acc: 0.091 - ETA: 3s - loss: 4.1557 - acc: 0.092 - ETA: 3s - loss: 4.1590 - acc: 0.091 - ETA: 3s - loss: 4.1603 - acc: 0.091 - ETA: 3s - loss: 4.1576 - acc: 0.090 - ETA: 3s - loss: 4.1582 - acc: 0.090 - ETA: 3s - loss: 4.1597 - acc: 0.090 - ETA: 3s - loss: 4.1586 - acc: 0.090 - ETA: 3s - loss: 4.1638 - acc: 0.089 - ETA: 3s - loss: 4.1621 - acc: 0.090 - ETA: 3s - loss: 4.1634 - acc: 0.090 - ETA: 3s - loss: 4.1629 - acc: 0.089 - ETA: 3s - loss: 4.1639 - acc: 0.089 - ETA: 3s - loss: 4.1684 - acc: 0.088 - ETA: 3s - loss: 4.1710 - acc: 0.088 - ETA: 2s - loss: 4.1713 - acc: 0.088 - ETA: 2s - loss: 4.1727 - acc: 0.088 - ETA: 2s - loss: 4.1736 - acc: 0.088 - ETA: 2s - loss: 4.1753 - acc: 0.087 - ETA: 2s - loss: 4.1779 - acc: 0.087 - ETA: 2s - loss: 4.1780 - acc: 0.087 - ETA: 2s - loss: 4.1776 - acc: 0.087 - ETA: 2s - loss: 4.1758 - acc: 0.087 - ETA: 2s - loss: 4.1769 - acc: 0.087 - ETA: 2s - loss: 4.1784 - acc: 0.087 - ETA: 2s - loss: 4.1785 - acc: 0.087 - ETA: 2s - loss: 4.1763 - acc: 0.087 - ETA: 2s - loss: 4.1754 - acc: 0.088 - ETA: 2s - loss: 4.1755 - acc: 0.088 - ETA: 2s - loss: 4.1789 - acc: 0.087 - ETA: 1s - loss: 4.1816 - acc: 0.087 - ETA: 1s - loss: 4.1821 - acc: 0.086 - ETA: 1s - loss: 4.1827 - acc: 0.086 - ETA: 1s - loss: 4.1835 - acc: 0.086 - ETA: 1s - loss: 4.1859 - acc: 0.085 - ETA: 1s - loss: 4.1862 - acc: 0.085 - ETA: 1s - loss: 4.1856 - acc: 0.085 - ETA: 1s - loss: 4.1866 - acc: 0.085 - ETA: 1s - loss: 4.1864 - acc: 0.085 - ETA: 1s - loss: 4.1885 - acc: 0.084 - ETA: 1s - loss: 4.1910 - acc: 0.084 - ETA: 1s - loss: 4.1887 - acc: 0.083 - ETA: 1s - loss: 4.1871 - acc: 0.083 - ETA: 1s - loss: 4.1901 - acc: 0.082 - ETA: 1s - loss: 4.1950 - acc: 0.082 - ETA: 0s - loss: 4.1977 - acc: 0.082 - ETA: 0s - loss: 4.1962 - acc: 0.082 - ETA: 0s - loss: 4.1958 - acc: 0.082 - ETA: 0s - loss: 4.1968 - acc: 0.082 - ETA: 0s - loss: 4.1976 - acc: 0.083 - ETA: 0s - loss: 4.1966 - acc: 0.083 - ETA ...
# 6680/6680 [==============================] - 8s - loss: 4.2016 - acc: 0.0832 - val_loss: 4.3359 - val_acc: 0.0695
# Epoch 10/10
# 6660/6680 [============================>.] - ETA: 7s - loss: 3.7896 - acc: 0.150 - ETA: 7s - loss: 4.0143 - acc: 0.112 - ETA: 7s - loss: 4.1130 - acc: 0.085 - ETA: 6s - loss: 4.1120 - acc: 0.095 - ETA: 6s - loss: 4.1201 - acc: 0.096 - ETA: 6s - loss: 4.1495 - acc: 0.096 - ETA: 6s - loss: 4.1348 - acc: 0.100 - ETA: 6s - loss: 4.1140 - acc: 0.104 - ETA: 6s - loss: 4.1242 - acc: 0.104 - ETA: 6s - loss: 4.1380 - acc: 0.105 - ETA: 6s - loss: 4.1464 - acc: 0.112 - ETA: 6s - loss: 4.1263 - acc: 0.111 - ETA: 6s - loss: 4.1170 - acc: 0.109 - ETA: 6s - loss: 4.1066 - acc: 0.108 - ETA: 6s - loss: 4.1135 - acc: 0.107 - ETA: 6s - loss: 4.1233 - acc: 0.107 - ETA: 6s - loss: 4.1278 - acc: 0.106 - ETA: 6s - loss: 4.1235 - acc: 0.105 - ETA: 6s - loss: 4.1326 - acc: 0.102 - ETA: 5s - loss: 4.1206 - acc: 0.102 - ETA: 5s - loss: 4.1259 - acc: 0.103 - ETA: 5s - loss: 4.1275 - acc: 0.103 - ETA: 5s - loss: 4.1397 - acc: 0.100 - ETA: 5s - loss: 4.1366 - acc: 0.100 - ETA: 5s - loss: 4.1345 - acc: 0.098 - ETA: 5s - loss: 4.1265 - acc: 0.100 - ETA: 5s - loss: 4.1251 - acc: 0.101 - ETA: 5s - loss: 4.1275 - acc: 0.101 - ETA: 5s - loss: 4.1312 - acc: 0.100 - ETA: 5s - loss: 4.1302 - acc: 0.101 - ETA: 5s - loss: 4.1332 - acc: 0.101 - ETA: 5s - loss: 4.1364 - acc: 0.101 - ETA: 5s - loss: 4.1390 - acc: 0.099 - ETA: 5s - loss: 4.1432 - acc: 0.098 - ETA: 5s - loss: 4.1429 - acc: 0.098 - ETA: 5s - loss: 4.1490 - acc: 0.095 - ETA: 4s - loss: 4.1421 - acc: 0.098 - ETA: 4s - loss: 4.1369 - acc: 0.100 - ETA: 4s - loss: 4.1416 - acc: 0.097 - ETA: 4s - loss: 4.1419 - acc: 0.097 - ETA: 4s - loss: 4.1392 - acc: 0.097 - ETA: 4s - loss: 4.1414 - acc: 0.095 - ETA: 4s - loss: 4.1413 - acc: 0.094 - ETA: 4s - loss: 4.1402 - acc: 0.096 - ETA: 4s - loss: 4.1451 - acc: 0.095 - ETA: 4s - loss: 4.1457 - acc: 0.094 - ETA: 4s - loss: 4.1464 - acc: 0.093 - ETA: 4s - loss: 4.1421 - acc: 0.095 - ETA: 4s - loss: 4.1461 - acc: 0.094 - ETA: 4s - loss: 4.1429 - acc: 0.096 - ETA: 4s - loss: 4.1437 - acc: 0.096 - ETA: 3s - loss: 4.1518 - acc: 0.094 - ETA: 3s - loss: 4.1539 - acc: 0.094 - ETA: 3s - loss: 4.1549 - acc: 0.093 - ETA: 3s - loss: 4.1561 - acc: 0.093 - ETA: 3s - loss: 4.1537 - acc: 0.093 - ETA: 3s - loss: 4.1536 - acc: 0.092 - ETA: 3s - loss: 4.1498 - acc: 0.091 - ETA: 3s - loss: 4.1470 - acc: 0.092 - ETA: 3s - loss: 4.1471 - acc: 0.092 - ETA: 3s - loss: 4.1512 - acc: 0.092 - ETA: 3s - loss: 4.1509 - acc: 0.092 - ETA: 3s - loss: 4.1498 - acc: 0.093 - ETA: 3s - loss: 4.1479 - acc: 0.092 - ETA: 3s - loss: 4.1518 - acc: 0.092 - ETA: 3s - loss: 4.1541 - acc: 0.091 - ETA: 2s - loss: 4.1562 - acc: 0.091 - ETA: 2s - loss: 4.1575 - acc: 0.089 - ETA: 2s - loss: 4.1570 - acc: 0.090 - ETA: 2s - loss: 4.1587 - acc: 0.090 - ETA: 2s - loss: 4.1625 - acc: 0.089 - ETA: 2s - loss: 4.1619 - acc: 0.089 - ETA: 2s - loss: 4.1625 - acc: 0.089 - ETA: 2s - loss: 4.1633 - acc: 0.089 - ETA: 2s - loss: 4.1630 - acc: 0.089 - ETA: 2s - loss: 4.1654 - acc: 0.088 - ETA: 2s - loss: 4.1630 - acc: 0.089 - ETA: 2s - loss: 4.1661 - acc: 0.089 - ETA: 2s - loss: 4.1653 - acc: 0.089 - ETA: 2s - loss: 4.1640 - acc: 0.089 - ETA: 2s - loss: 4.1643 - acc: 0.089 - ETA: 2s - loss: 4.1684 - acc: 0.089 - ETA: 1s - loss: 4.1680 - acc: 0.089 - ETA: 1s - loss: 4.1682 - acc: 0.089 - ETA: 1s - loss: 4.1683 - acc: 0.089 - ETA: 1s - loss: 4.1682 - acc: 0.089 - ETA: 1s - loss: 4.1699 - acc: 0.089 - ETA: 1s - loss: 4.1678 - acc: 0.090 - ETA: 1s - loss: 4.1683 - acc: 0.089 - ETA: 1s - loss: 4.1653 - acc: 0.090 - ETA: 1s - loss: 4.1642 - acc: 0.089 - ETA: 1s - loss: 4.1669 - acc: 0.089 - ETA: 1s - loss: 4.1635 - acc: 0.090 - ETA: 1s - loss: 4.1619 - acc: 0.090 - ETA: 1s - loss: 4.1615 - acc: 0.090 - ETA: 1s - loss: 4.1603 - acc: 0.091 - ETA: 1s - loss: 4.1623 - acc: 0.090 - ETA: 0s - loss: 4.1612 - acc: 0.091 - ETA: 0s - loss: 4.1586 - acc: 0.091 - ETA: 0s - loss: 4.1576 - acc: 0.091 - ETA: 0s - loss: 4.1573 - acc: 0.090 - ETA: 0s - loss: 4.1571 - acc: 0.090 - ETA: 0s - loss: 4.1570 - acc: 0.090 - ETA: 0s - loss: 4.1587 - acc: 0.090 - ETA ...
# 6680/6680 [==============================] - 7s - loss: 4.1621 - acc: 0.0889 - val_loss: 4.3119 - val_acc: 0.0635

# %%
# summarize history for accuracy
plt.plot(model_history.history['acc'])
plt.plot(model_history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
## 加载具有最好验证loss的模型

model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### 测试模型
#
# 在狗图像的测试数据集上试用你的模型。确保测试准确率大于1%。

# %%
# 获取测试数据集中每一个图像所预测的狗品种的index
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# 报告测试准确率
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 7.6555%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## 步骤 4: 使用一个CNN来区分狗的品种
#
#
# 使用 迁移学习（Transfer Learning）的方法，能帮助我们在不损失准确率的情况下大大减少训练时间。在以下步骤中，你可以尝试使用迁移学习来训练你自己的CNN。

# %% [markdown]
# ### 得到从图像中提取的特征向量（Bottleneck Features）

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### 模型架构
#
# 该模型使用预训练的 VGG-16 模型作为固定的图像特征提取器，其中 VGG-16 最后一层卷积层的输出被直接输入到我们的模型。我们只需要添加一个全局平均池化层以及一个全连接层，其中全连接层使用 softmax 激活函数，对每一个狗的种类都包含一个节点。

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229.0
# Trainable params: 68,229.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
## 编译模型

VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
## 训练模型

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

history = VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6520/6680 [============================>.] - ETA: 89s - loss: 15.4919 - acc: 0.0000e+0 - ETA: 11s - loss: 14.8211 - acc: 0.0167    - ETA: 6s - loss: 14.5608 - acc: 0.019 - ETA: 5s - loss: 14.3548 - acc: 0.02 - ETA: 4s - loss: 14.3113 - acc: 0.03 - ETA: 3s - loss: 14.1893 - acc: 0.02 - ETA: 3s - loss: 14.0694 - acc: 0.02 - ETA: 2s - loss: 13.9101 - acc: 0.03 - ETA: 2s - loss: 13.7726 - acc: 0.04 - ETA: 2s - loss: 13.7720 - acc: 0.04 - ETA: 2s - loss: 13.6795 - acc: 0.04 - ETA: 2s - loss: 13.5318 - acc: 0.05 - ETA: 1s - loss: 13.4499 - acc: 0.05 - ETA: 1s - loss: 13.4321 - acc: 0.05 - ETA: 1s - loss: 13.3456 - acc: 0.05 - ETA: 1s - loss: 13.2884 - acc: 0.05 - ETA: 1s - loss: 13.1651 - acc: 0.06 - ETA: 1s - loss: 13.0961 - acc: 0.06 - ETA: 1s - loss: 13.0672 - acc: 0.06 - ETA: 1s - loss: 12.9997 - acc: 0.07 - ETA: 1s - loss: 12.9414 - acc: 0.07 - ETA: 1s - loss: 12.8223 - acc: 0.08 - ETA: 1s - loss: 12.7646 - acc: 0.08 - ETA: 0s - loss: 12.7354 - acc: 0.08 - ETA: 0s - loss: 12.6965 - acc: 0.09 - ETA: 0s - loss: 12.6362 - acc: 0.09 - ETA: 0s - loss: 12.6001 - acc: 0.09 - ETA: 0s - loss: 12.5172 - acc: 0.10 - ETA: 0s - loss: 12.4301 - acc: 0.10 - ETA: 0s - loss: 12.4084 - acc: 0.10 - ETA: 0s - loss: 12.3894 - acc: 0.10 - ETA: 0s - loss: 12.3467 - acc: 0.11 - ETA: 0s - loss: 12.2809 - acc: 0.11 - ETA: 0s - loss: 12.2310 - acc: 0.11 - ETA: 0s - loss: 12.1887 - acc: 0.11 - ETA: 0s - loss: 12.1370 - acc: 0.12 - ETA: 0s - loss: 12.0792 - acc: 0.12 - ETA: 0s - loss: 12.0579 - acc: 0.1278Epoch 00000: val_loss improved from inf to 10.35098, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 12.0323 - acc: 0.1289 - val_loss: 10.3510 - val_acc: 0.2323
# Epoch 2/20
# 6640/6680 [============================>.] - ETA: 1s - loss: 11.6092 - acc: 0.20 - ETA: 1s - loss: 11.2328 - acc: 0.20 - ETA: 1s - loss: 10.6247 - acc: 0.23 - ETA: 1s - loss: 10.8517 - acc: 0.21 - ETA: 1s - loss: 10.7441 - acc: 0.22 - ETA: 1s - loss: 10.6169 - acc: 0.23 - ETA: 1s - loss: 10.4969 - acc: 0.24 - ETA: 1s - loss: 10.4391 - acc: 0.24 - ETA: 1s - loss: 10.3307 - acc: 0.25 - ETA: 1s - loss: 10.2737 - acc: 0.25 - ETA: 1s - loss: 10.1535 - acc: 0.26 - ETA: 1s - loss: 10.0323 - acc: 0.27 - ETA: 1s - loss: 9.9736 - acc: 0.2759 - ETA: 1s - loss: 9.9454 - acc: 0.277 - ETA: 1s - loss: 9.9021 - acc: 0.280 - ETA: 1s - loss: 9.8967 - acc: 0.281 - ETA: 1s - loss: 9.8739 - acc: 0.283 - ETA: 1s - loss: 9.8009 - acc: 0.289 - ETA: 1s - loss: 9.7859 - acc: 0.290 - ETA: 0s - loss: 9.8287 - acc: 0.287 - ETA: 0s - loss: 9.8222 - acc: 0.288 - ETA: 0s - loss: 9.7940 - acc: 0.289 - ETA: 0s - loss: 9.8005 - acc: 0.288 - ETA: 0s - loss: 9.7821 - acc: 0.289 - ETA: 0s - loss: 9.7447 - acc: 0.292 - ETA: 0s - loss: 9.7417 - acc: 0.292 - ETA: 0s - loss: 9.7342 - acc: 0.292 - ETA: 0s - loss: 9.7086 - acc: 0.293 - ETA: 0s - loss: 9.6770 - acc: 0.295 - ETA: 0s - loss: 9.6748 - acc: 0.296 - ETA: 0s - loss: 9.6937 - acc: 0.296 - ETA: 0s - loss: 9.6580 - acc: 0.298 - ETA: 0s - loss: 9.6761 - acc: 0.298 - ETA: 0s - loss: 9.6869 - acc: 0.298 - ETA: 0s - loss: 9.6607 - acc: 0.299 - ETA: 0s - loss: 9.6599 - acc: 0.299 - ETA: 0s - loss: 9.6574 - acc: 0.299 - ETA: 0s - loss: 9.6433 - acc: 0.2997Epoch 00001: val_loss improved from 10.35098 to 9.47842, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 9.6481 - acc: 0.2994 - val_loss: 9.4784 - val_acc: 0.3353
# Epoch 3/20
# 6600/6680 [============================>.] - ETA: 2s - loss: 5.9281 - acc: 0.550 - ETA: 2s - loss: 8.7589 - acc: 0.400 - ETA: 1s - loss: 9.1111 - acc: 0.389 - ETA: 1s - loss: 8.9881 - acc: 0.383 - ETA: 1s - loss: 9.0278 - acc: 0.385 - ETA: 1s - loss: 8.9940 - acc: 0.387 - ETA: 1s - loss: 8.8207 - acc: 0.396 - ETA: 1s - loss: 8.7706 - acc: 0.397 - ETA: 1s - loss: 8.8603 - acc: 0.390 - ETA: 1s - loss: 8.7880 - acc: 0.397 - ETA: 1s - loss: 8.9070 - acc: 0.388 - ETA: 1s - loss: 8.8765 - acc: 0.390 - ETA: 1s - loss: 8.8982 - acc: 0.387 - ETA: 1s - loss: 8.8908 - acc: 0.386 - ETA: 1s - loss: 8.9157 - acc: 0.383 - ETA: 1s - loss: 8.9597 - acc: 0.380 - ETA: 1s - loss: 8.9982 - acc: 0.377 - ETA: 1s - loss: 8.9593 - acc: 0.379 - ETA: 0s - loss: 8.9676 - acc: 0.380 - ETA: 0s - loss: 8.9706 - acc: 0.380 - ETA: 0s - loss: 8.9830 - acc: 0.378 - ETA: 0s - loss: 8.9428 - acc: 0.381 - ETA: 0s - loss: 8.9631 - acc: 0.380 - ETA: 0s - loss: 9.0126 - acc: 0.377 - ETA: 0s - loss: 9.0645 - acc: 0.374 - ETA: 0s - loss: 9.0575 - acc: 0.373 - ETA: 0s - loss: 9.0592 - acc: 0.374 - ETA: 0s - loss: 9.0436 - acc: 0.376 - ETA: 0s - loss: 9.0857 - acc: 0.374 - ETA: 0s - loss: 9.0835 - acc: 0.375 - ETA: 0s - loss: 9.0713 - acc: 0.376 - ETA: 0s - loss: 9.0837 - acc: 0.375 - ETA: 0s - loss: 9.0943 - acc: 0.373 - ETA: 0s - loss: 9.1110 - acc: 0.372 - ETA: 0s - loss: 9.1099 - acc: 0.372 - ETA: 0s - loss: 9.1090 - acc: 0.3735Epoch 00002: val_loss improved from 9.47842 to 9.41075, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 9.1178 - acc: 0.3732 - val_loss: 9.4108 - val_acc: 0.3341
# Epoch 4/20
# 6540/6680 [============================>.] - ETA: 2s - loss: 10.4045 - acc: 0.30 - ETA: 1s - loss: 9.0721 - acc: 0.4000 - ETA: 2s - loss: 8.8785 - acc: 0.416 - ETA: 1s - loss: 9.1171 - acc: 0.400 - ETA: 1s - loss: 8.8543 - acc: 0.408 - ETA: 1s - loss: 8.7199 - acc: 0.417 - ETA: 1s - loss: 8.8218 - acc: 0.410 - ETA: 1s - loss: 8.8215 - acc: 0.407 - ETA: 1s - loss: 8.9095 - acc: 0.402 - ETA: 1s - loss: 8.9475 - acc: 0.400 - ETA: 1s - loss: 9.0074 - acc: 0.397 - ETA: 1s - loss: 8.9480 - acc: 0.402 - ETA: 1s - loss: 8.8617 - acc: 0.409 - ETA: 1s - loss: 8.8347 - acc: 0.412 - ETA: 1s - loss: 8.9145 - acc: 0.407 - ETA: 1s - loss: 8.9024 - acc: 0.408 - ETA: 1s - loss: 8.8539 - acc: 0.411 - ETA: 1s - loss: 8.8504 - acc: 0.410 - ETA: 0s - loss: 8.8443 - acc: 0.409 - ETA: 0s - loss: 8.8443 - acc: 0.410 - ETA: 0s - loss: 8.8905 - acc: 0.406 - ETA: 0s - loss: 8.8986 - acc: 0.405 - ETA: 0s - loss: 8.9250 - acc: 0.404 - ETA: 0s - loss: 8.9089 - acc: 0.404 - ETA: 0s - loss: 8.8713 - acc: 0.406 - ETA: 0s - loss: 8.8790 - acc: 0.405 - ETA: 0s - loss: 8.8635 - acc: 0.407 - ETA: 0s - loss: 8.8699 - acc: 0.406 - ETA: 0s - loss: 8.8797 - acc: 0.405 - ETA: 0s - loss: 8.9013 - acc: 0.404 - ETA: 0s - loss: 8.8955 - acc: 0.404 - ETA: 0s - loss: 8.8906 - acc: 0.404 - ETA: 0s - loss: 8.9014 - acc: 0.402 - ETA: 0s - loss: 8.8966 - acc: 0.403 - ETA: 0s - loss: 8.8893 - acc: 0.403 - ETA: 0s - loss: 8.8748 - acc: 0.403 - ETA: 0s - loss: 8.8657 - acc: 0.4043Epoch 00003: val_loss improved from 9.41075 to 9.31953, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 8.8676 - acc: 0.4042 - val_loss: 9.3195 - val_acc: 0.3533
# Epoch 5/20
# 6480/6680 [============================>.] - ETA: 1s - loss: 6.5458 - acc: 0.550 - ETA: 1s - loss: 8.6066 - acc: 0.445 - ETA: 1s - loss: 8.1128 - acc: 0.476 - ETA: 1s - loss: 8.3243 - acc: 0.458 - ETA: 1s - loss: 8.3984 - acc: 0.450 - ETA: 1s - loss: 8.5334 - acc: 0.442 - ETA: 1s - loss: 8.5887 - acc: 0.441 - ETA: 1s - loss: 8.5558 - acc: 0.443 - ETA: 1s - loss: 8.6351 - acc: 0.435 - ETA: 1s - loss: 8.6259 - acc: 0.436 - ETA: 1s - loss: 8.7740 - acc: 0.426 - ETA: 1s - loss: 8.7571 - acc: 0.428 - ETA: 1s - loss: 8.8313 - acc: 0.422 - ETA: 1s - loss: 8.7775 - acc: 0.424 - ETA: 1s - loss: 8.7075 - acc: 0.428 - ETA: 1s - loss: 8.7075 - acc: 0.428 - ETA: 1s - loss: 8.6805 - acc: 0.430 - ETA: 1s - loss: 8.6746 - acc: 0.431 - ETA: 0s - loss: 8.6579 - acc: 0.431 - ETA: 0s - loss: 8.6497 - acc: 0.430 - ETA: 0s - loss: 8.6295 - acc: 0.431 - ETA: 0s - loss: 8.5925 - acc: 0.432 - ETA: 0s - loss: 8.5857 - acc: 0.433 - ETA: 0s - loss: 8.5770 - acc: 0.433 - ETA: 0s - loss: 8.6053 - acc: 0.432 - ETA: 0s - loss: 8.6010 - acc: 0.431 - ETA: 0s - loss: 8.6081 - acc: 0.430 - ETA: 0s - loss: 8.6177 - acc: 0.429 - ETA: 0s - loss: 8.6188 - acc: 0.430 - ETA: 0s - loss: 8.6352 - acc: 0.429 - ETA: 0s - loss: 8.6529 - acc: 0.427 - ETA: 0s - loss: 8.6630 - acc: 0.427 - ETA: 0s - loss: 8.6519 - acc: 0.428 - ETA: 0s - loss: 8.6065 - acc: 0.430 - ETA: 0s - loss: 8.5935 - acc: 0.430 - ETA: 0s - loss: 8.6160 - acc: 0.4293Epoch 00004: val_loss improved from 9.31953 to 9.15544, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 8.6189 - acc: 0.4293 - val_loss: 9.1554 - val_acc: 0.3641
# Epoch 6/20
# 6540/6680 [============================>.] - ETA: 2s - loss: 5.7256 - acc: 0.600 - ETA: 1s - loss: 7.7676 - acc: 0.504 - ETA: 2s - loss: 8.1746 - acc: 0.481 - ETA: 1s - loss: 8.3268 - acc: 0.468 - ETA: 1s - loss: 8.5137 - acc: 0.452 - ETA: 1s - loss: 8.4498 - acc: 0.454 - ETA: 1s - loss: 8.5680 - acc: 0.447 - ETA: 1s - loss: 8.7587 - acc: 0.435 - ETA: 1s - loss: 8.7710 - acc: 0.432 - ETA: 1s - loss: 8.7954 - acc: 0.432 - ETA: 1s - loss: 8.7283 - acc: 0.435 - ETA: 1s - loss: 8.6643 - acc: 0.440 - ETA: 1s - loss: 8.5628 - acc: 0.446 - ETA: 1s - loss: 8.5740 - acc: 0.445 - ETA: 1s - loss: 8.6283 - acc: 0.443 - ETA: 1s - loss: 8.6069 - acc: 0.444 - ETA: 1s - loss: 8.5785 - acc: 0.445 - ETA: 1s - loss: 8.5084 - acc: 0.448 - ETA: 1s - loss: 8.5540 - acc: 0.445 - ETA: 0s - loss: 8.4763 - acc: 0.450 - ETA: 0s - loss: 8.5047 - acc: 0.447 - ETA: 0s - loss: 8.5602 - acc: 0.444 - ETA: 0s - loss: 8.5505 - acc: 0.444 - ETA: 0s - loss: 8.5356 - acc: 0.445 - ETA: 0s - loss: 8.5138 - acc: 0.446 - ETA: 0s - loss: 8.4849 - acc: 0.448 - ETA: 0s - loss: 8.4803 - acc: 0.447 - ETA: 0s - loss: 8.4635 - acc: 0.448 - ETA: 0s - loss: 8.4878 - acc: 0.447 - ETA: 0s - loss: 8.4736 - acc: 0.447 - ETA: 0s - loss: 8.4933 - acc: 0.445 - ETA: 0s - loss: 8.4664 - acc: 0.447 - ETA: 0s - loss: 8.4833 - acc: 0.446 - ETA: 0s - loss: 8.5054 - acc: 0.445 - ETA: 0s - loss: 8.5019 - acc: 0.444 - ETA: 0s - loss: 8.4974 - acc: 0.444 - ETA: 0s - loss: 8.5240 - acc: 0.4433Epoch 00005: val_loss improved from 9.15544 to 8.98472, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 8.5093 - acc: 0.4440 - val_loss: 8.9847 - val_acc: 0.3856
# Epoch 7/20
# 6580/6680 [============================>.] - ETA: 2s - loss: 8.9999 - acc: 0.400 - ETA: 1s - loss: 8.5114 - acc: 0.455 - ETA: 1s - loss: 8.8651 - acc: 0.426 - ETA: 1s - loss: 8.6231 - acc: 0.437 - ETA: 1s - loss: 8.8115 - acc: 0.429 - ETA: 1s - loss: 8.8092 - acc: 0.432 - ETA: 1s - loss: 8.8655 - acc: 0.430 - ETA: 1s - loss: 8.7796 - acc: 0.434 - ETA: 1s - loss: 8.8163 - acc: 0.434 - ETA: 1s - loss: 8.7087 - acc: 0.442 - ETA: 1s - loss: 8.7278 - acc: 0.440 - ETA: 1s - loss: 8.6333 - acc: 0.446 - ETA: 1s - loss: 8.5526 - acc: 0.451 - ETA: 1s - loss: 8.5244 - acc: 0.453 - ETA: 1s - loss: 8.5904 - acc: 0.449 - ETA: 1s - loss: 8.5997 - acc: 0.449 - ETA: 1s - loss: 8.5860 - acc: 0.450 - ETA: 1s - loss: 8.5862 - acc: 0.450 - ETA: 0s - loss: 8.6291 - acc: 0.447 - ETA: 0s - loss: 8.6616 - acc: 0.445 - ETA: 0s - loss: 8.6229 - acc: 0.447 - ETA: 0s - loss: 8.6312 - acc: 0.447 - ETA: 0s - loss: 8.6125 - acc: 0.448 - ETA: 0s - loss: 8.6178 - acc: 0.447 - ETA: 0s - loss: 8.6171 - acc: 0.447 - ETA: 0s - loss: 8.5837 - acc: 0.449 - ETA: 0s - loss: 8.5482 - acc: 0.450 - ETA: 0s - loss: 8.5507 - acc: 0.449 - ETA: 0s - loss: 8.5322 - acc: 0.450 - ETA: 0s - loss: 8.5201 - acc: 0.450 - ETA: 0s - loss: 8.4900 - acc: 0.452 - ETA: 0s - loss: 8.4717 - acc: 0.453 - ETA: 0s - loss: 8.4729 - acc: 0.452 - ETA: 0s - loss: 8.4448 - acc: 0.454 - ETA: 0s - loss: 8.4344 - acc: 0.455 - ETA: 0s - loss: 8.4312 - acc: 0.454 - ETA: 0s - loss: 8.4284 - acc: 0.4543Epoch 00006: val_loss improved from 8.98472 to 8.86797, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 8.4069 - acc: 0.4555 - val_loss: 8.8680 - val_acc: 0.3952
# Epoch 8/20
# 6500/6680 [============================>.] - ETA: 1s - loss: 8.8650 - acc: 0.450 - ETA: 1s - loss: 7.7393 - acc: 0.495 - ETA: 1s - loss: 8.0039 - acc: 0.481 - ETA: 1s - loss: 7.9411 - acc: 0.491 - ETA: 1s - loss: 8.2002 - acc: 0.473 - ETA: 1s - loss: 8.1796 - acc: 0.476 - ETA: 1s - loss: 8.1069 - acc: 0.480 - ETA: 1s - loss: 8.1091 - acc: 0.481 - ETA: 1s - loss: 8.2231 - acc: 0.473 - ETA: 1s - loss: 8.2716 - acc: 0.470 - ETA: 1s - loss: 8.2533 - acc: 0.472 - ETA: 1s - loss: 8.3555 - acc: 0.465 - ETA: 1s - loss: 8.3221 - acc: 0.465 - ETA: 1s - loss: 8.2994 - acc: 0.466 - ETA: 1s - loss: 8.1995 - acc: 0.472 - ETA: 1s - loss: 8.3072 - acc: 0.467 - ETA: 1s - loss: 8.3223 - acc: 0.466 - ETA: 1s - loss: 8.2802 - acc: 0.468 - ETA: 0s - loss: 8.2101 - acc: 0.472 - ETA: 0s - loss: 8.1838 - acc: 0.473 - ETA: 0s - loss: 8.1445 - acc: 0.475 - ETA: 0s - loss: 8.1588 - acc: 0.475 - ETA: 0s - loss: 8.2048 - acc: 0.472 - ETA: 0s - loss: 8.2047 - acc: 0.472 - ETA: 0s - loss: 8.2012 - acc: 0.472 - ETA: 0s - loss: 8.2124 - acc: 0.472 - ETA: 0s - loss: 8.2086 - acc: 0.473 - ETA: 0s - loss: 8.2242 - acc: 0.472 - ETA: 0s - loss: 8.2201 - acc: 0.472 - ETA: 0s - loss: 8.2641 - acc: 0.469 - ETA: 0s - loss: 8.2533 - acc: 0.470 - ETA: 0s - loss: 8.2765 - acc: 0.469 - ETA: 0s - loss: 8.2575 - acc: 0.470 - ETA: 0s - loss: 8.2424 - acc: 0.471 - ETA: 0s - loss: 8.2554 - acc: 0.470 - ETA: 0s - loss: 8.2734 - acc: 0.469 - ETA: 0s - loss: 8.2759 - acc: 0.4694Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 8.2874 - acc: 0.4687 - val_loss: 8.9354 - val_acc: 0.3856
# Epoch 9/20
# 6660/6680 [============================>.] - ETA: 2s - loss: 8.8667 - acc: 0.450 - ETA: 2s - loss: 8.2863 - acc: 0.470 - ETA: 1s - loss: 7.7644 - acc: 0.507 - ETA: 1s - loss: 7.9724 - acc: 0.496 - ETA: 1s - loss: 8.0596 - acc: 0.488 - ETA: 1s - loss: 8.2133 - acc: 0.475 - ETA: 1s - loss: 8.1859 - acc: 0.474 - ETA: 1s - loss: 8.1749 - acc: 0.476 - ETA: 1s - loss: 8.1658 - acc: 0.472 - ETA: 1s - loss: 8.2952 - acc: 0.464 - ETA: 1s - loss: 8.3126 - acc: 0.464 - ETA: 1s - loss: 8.3508 - acc: 0.463 - ETA: 1s - loss: 8.3195 - acc: 0.465 - ETA: 1s - loss: 8.3651 - acc: 0.463 - ETA: 1s - loss: 8.2668 - acc: 0.469 - ETA: 1s - loss: 8.2264 - acc: 0.472 - ETA: 1s - loss: 8.2571 - acc: 0.470 - ETA: 1s - loss: 8.2453 - acc: 0.471 - ETA: 1s - loss: 8.2587 - acc: 0.470 - ETA: 0s - loss: 8.2407 - acc: 0.471 - ETA: 0s - loss: 8.2265 - acc: 0.471 - ETA: 0s - loss: 8.2290 - acc: 0.471 - ETA: 0s - loss: 8.2219 - acc: 0.471 - ETA: 0s - loss: 8.2217 - acc: 0.471 - ETA: 0s - loss: 8.2370 - acc: 0.469 - ETA: 0s - loss: 8.2077 - acc: 0.471 - ETA: 0s - loss: 8.2330 - acc: 0.470 - ETA: 0s - loss: 8.2252 - acc: 0.471 - ETA: 0s - loss: 8.2256 - acc: 0.470 - ETA: 0s - loss: 8.2481 - acc: 0.469 - ETA: 0s - loss: 8.2603 - acc: 0.468 - ETA: 0s - loss: 8.2564 - acc: 0.469 - ETA: 0s - loss: 8.2491 - acc: 0.470 - ETA: 0s - loss: 8.2641 - acc: 0.469 - ETA: 0s - loss: 8.2267 - acc: 0.471 - ETA: 0s - loss: 8.2078 - acc: 0.473 - ETA: 0s - loss: 8.2099 - acc: 0.4731Epoch 00008: val_loss improved from 8.86797 to 8.74483, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 8.2095 - acc: 0.4732 - val_loss: 8.7448 - val_acc: 0.3988
# Epoch 10/20
# 6500/6680 [============================>.] - ETA: 2s - loss: 6.4810 - acc: 0.600 - ETA: 1s - loss: 7.6272 - acc: 0.525 - ETA: 1s - loss: 7.4991 - acc: 0.531 - ETA: 1s - loss: 7.9055 - acc: 0.501 - ETA: 1s - loss: 7.9674 - acc: 0.498 - ETA: 1s - loss: 8.0687 - acc: 0.487 - ETA: 1s - loss: 8.0798 - acc: 0.487 - ETA: 1s - loss: 8.0589 - acc: 0.488 - ETA: 1s - loss: 8.0964 - acc: 0.486 - ETA: 1s - loss: 8.0358 - acc: 0.490 - ETA: 1s - loss: 8.0268 - acc: 0.491 - ETA: 1s - loss: 8.0756 - acc: 0.488 - ETA: 1s - loss: 8.0315 - acc: 0.491 - ETA: 1s - loss: 8.0145 - acc: 0.492 - ETA: 1s - loss: 7.9997 - acc: 0.493 - ETA: 1s - loss: 7.9765 - acc: 0.493 - ETA: 1s - loss: 8.0317 - acc: 0.490 - ETA: 1s - loss: 8.0567 - acc: 0.488 - ETA: 1s - loss: 8.0918 - acc: 0.486 - ETA: 1s - loss: 8.1287 - acc: 0.485 - ETA: 0s - loss: 8.1348 - acc: 0.485 - ETA: 0s - loss: 8.1676 - acc: 0.483 - ETA: 0s - loss: 8.1509 - acc: 0.484 - ETA: 0s - loss: 8.1344 - acc: 0.485 - ETA: 0s - loss: 8.1564 - acc: 0.483 - ETA: 0s - loss: 8.1456 - acc: 0.484 - ETA: 0s - loss: 8.1285 - acc: 0.485 - ETA: 0s - loss: 8.1633 - acc: 0.482 - ETA: 0s - loss: 8.1552 - acc: 0.483 - ETA: 0s - loss: 8.1159 - acc: 0.485 - ETA: 0s - loss: 8.0854 - acc: 0.487 - ETA: 0s - loss: 8.1019 - acc: 0.487 - ETA: 0s - loss: 8.1070 - acc: 0.486 - ETA: 0s - loss: 8.1160 - acc: 0.486 - ETA: 0s - loss: 8.0923 - acc: 0.487 - ETA: 0s - loss: 8.0847 - acc: 0.487 - ETA: 0s - loss: 8.1224 - acc: 0.4843Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 8.1203 - acc: 0.4844 - val_loss: 8.7729 - val_acc: 0.4000
# Epoch 11/20
# 6520/6680 [============================>.] - ETA: 1s - loss: 8.9284 - acc: 0.400 - ETA: 1s - loss: 8.6351 - acc: 0.450 - ETA: 2s - loss: 7.9528 - acc: 0.491 - ETA: 1s - loss: 8.3766 - acc: 0.470 - ETA: 1s - loss: 8.2235 - acc: 0.478 - ETA: 1s - loss: 8.4516 - acc: 0.464 - ETA: 1s - loss: 8.3743 - acc: 0.465 - ETA: 1s - loss: 8.3486 - acc: 0.467 - ETA: 1s - loss: 8.3052 - acc: 0.469 - ETA: 1s - loss: 8.3285 - acc: 0.468 - ETA: 1s - loss: 8.2786 - acc: 0.472 - ETA: 1s - loss: 8.2188 - acc: 0.476 - ETA: 1s - loss: 8.2493 - acc: 0.475 - ETA: 1s - loss: 8.2419 - acc: 0.476 - ETA: 1s - loss: 8.2376 - acc: 0.476 - ETA: 1s - loss: 8.2334 - acc: 0.477 - ETA: 1s - loss: 8.2565 - acc: 0.476 - ETA: 1s - loss: 8.2492 - acc: 0.476 - ETA: 0s - loss: 8.2481 - acc: 0.476 - ETA: 0s - loss: 8.2183 - acc: 0.477 - ETA: 0s - loss: 8.2276 - acc: 0.477 - ETA: 0s - loss: 8.2040 - acc: 0.479 - ETA: 0s - loss: 8.2142 - acc: 0.478 - ETA: 0s - loss: 8.1741 - acc: 0.481 - ETA: 0s - loss: 8.1585 - acc: 0.482 - ETA: 0s - loss: 8.1857 - acc: 0.480 - ETA: 0s - loss: 8.1718 - acc: 0.480 - ETA: 0s - loss: 8.1528 - acc: 0.482 - ETA: 0s - loss: 8.1372 - acc: 0.482 - ETA: 0s - loss: 8.1075 - acc: 0.484 - ETA: 0s - loss: 8.1125 - acc: 0.484 - ETA: 0s - loss: 8.1128 - acc: 0.484 - ETA: 0s - loss: 8.0809 - acc: 0.486 - ETA: 0s - loss: 8.0614 - acc: 0.487 - ETA: 0s - loss: 8.0482 - acc: 0.488 - ETA: 0s - loss: 8.0712 - acc: 0.4871Epoch 00010: val_loss improved from 8.74483 to 8.69015, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 8.0696 - acc: 0.4871 - val_loss: 8.6901 - val_acc: 0.3988
# Epoch 12/20
# 6620/6680 [============================>.] - ETA: 2s - loss: 5.6440 - acc: 0.650 - ETA: 1s - loss: 7.7673 - acc: 0.515 - ETA: 1s - loss: 7.9267 - acc: 0.500 - ETA: 1s - loss: 7.6896 - acc: 0.514 - ETA: 1s - loss: 7.7163 - acc: 0.513 - ETA: 1s - loss: 7.9181 - acc: 0.501 - ETA: 1s - loss: 7.8666 - acc: 0.503 - ETA: 1s - loss: 7.9190 - acc: 0.500 - ETA: 1s - loss: 7.7905 - acc: 0.507 - ETA: 1s - loss: 7.8610 - acc: 0.502 - ETA: 1s - loss: 7.8247 - acc: 0.503 - ETA: 1s - loss: 7.8229 - acc: 0.503 - ETA: 1s - loss: 7.7854 - acc: 0.504 - ETA: 1s - loss: 7.8461 - acc: 0.501 - ETA: 1s - loss: 7.7913 - acc: 0.503 - ETA: 1s - loss: 7.8523 - acc: 0.500 - ETA: 1s - loss: 7.8203 - acc: 0.501 - ETA: 1s - loss: 7.7885 - acc: 0.503 - ETA: 1s - loss: 7.8118 - acc: 0.502 - ETA: 0s - loss: 7.7453 - acc: 0.506 - ETA: 0s - loss: 7.7716 - acc: 0.504 - ETA: 0s - loss: 7.7767 - acc: 0.504 - ETA: 0s - loss: 7.8114 - acc: 0.501 - ETA: 0s - loss: 7.7812 - acc: 0.503 - ETA: 0s - loss: 7.8296 - acc: 0.500 - ETA: 0s - loss: 7.8255 - acc: 0.501 - ETA: 0s - loss: 7.8316 - acc: 0.501 - ETA: 0s - loss: 7.8153 - acc: 0.502 - ETA: 0s - loss: 7.8285 - acc: 0.502 - ETA: 0s - loss: 7.8639 - acc: 0.500 - ETA: 0s - loss: 7.8682 - acc: 0.500 - ETA: 0s - loss: 7.9035 - acc: 0.497 - ETA: 0s - loss: 7.9113 - acc: 0.496 - ETA: 0s - loss: 7.9466 - acc: 0.494 - ETA: 0s - loss: 7.9382 - acc: 0.494 - ETA: 0s - loss: 7.9572 - acc: 0.493 - ETA: 0s - loss: 7.9562 - acc: 0.4931Epoch 00011: val_loss improved from 8.69015 to 8.60077, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 7.9549 - acc: 0.4933 - val_loss: 8.6008 - val_acc: 0.4156
# Epoch 13/20
# 6560/6680 [============================>.] - ETA: 2s - loss: 11.2827 - acc: 0.30 - ETA: 2s - loss: 8.2762 - acc: 0.4800 - ETA: 1s - loss: 7.8794 - acc: 0.507 - ETA: 1s - loss: 7.9285 - acc: 0.503 - ETA: 1s - loss: 8.1016 - acc: 0.491 - ETA: 1s - loss: 7.7090 - acc: 0.516 - ETA: 1s - loss: 7.9311 - acc: 0.501 - ETA: 1s - loss: 7.9154 - acc: 0.503 - ETA: 1s - loss: 7.8560 - acc: 0.506 - ETA: 1s - loss: 7.8659 - acc: 0.503 - ETA: 1s - loss: 7.8878 - acc: 0.501 - ETA: 1s - loss: 7.9423 - acc: 0.498 - ETA: 1s - loss: 8.0403 - acc: 0.491 - ETA: 1s - loss: 8.0835 - acc: 0.489 - ETA: 1s - loss: 8.0390 - acc: 0.492 - ETA: 1s - loss: 7.9344 - acc: 0.499 - ETA: 1s - loss: 7.9856 - acc: 0.496 - ETA: 1s - loss: 7.9918 - acc: 0.495 - ETA: 0s - loss: 7.9550 - acc: 0.498 - ETA: 0s - loss: 7.9194 - acc: 0.500 - ETA: 0s - loss: 7.9196 - acc: 0.500 - ETA: 0s - loss: 7.8894 - acc: 0.502 - ETA: 0s - loss: 7.8680 - acc: 0.503 - ETA: 0s - loss: 7.9180 - acc: 0.500 - ETA: 0s - loss: 7.8873 - acc: 0.502 - ETA: 0s - loss: 7.8732 - acc: 0.504 - ETA: 0s - loss: 7.8518 - acc: 0.505 - ETA: 0s - loss: 7.8782 - acc: 0.504 - ETA: 0s - loss: 7.8532 - acc: 0.505 - ETA: 0s - loss: 7.8339 - acc: 0.506 - ETA: 0s - loss: 7.8482 - acc: 0.505 - ETA: 0s - loss: 7.8759 - acc: 0.503 - ETA: 0s - loss: 7.8762 - acc: 0.503 - ETA: 0s - loss: 7.8741 - acc: 0.503 - ETA: 0s - loss: 7.8860 - acc: 0.503 - ETA: 0s - loss: 7.8638 - acc: 0.504 - ETA: 0s - loss: 7.8734 - acc: 0.5035Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 7.8690 - acc: 0.5036 - val_loss: 8.6384 - val_acc: 0.3976
# Epoch 14/20
# 6580/6680 [============================>.] - ETA: 2s - loss: 9.1754 - acc: 0.400 - ETA: 1s - loss: 7.3720 - acc: 0.530 - ETA: 1s - loss: 7.5474 - acc: 0.518 - ETA: 1s - loss: 7.7439 - acc: 0.509 - ETA: 1s - loss: 7.5141 - acc: 0.521 - ETA: 1s - loss: 7.6605 - acc: 0.511 - ETA: 1s - loss: 7.8066 - acc: 0.501 - ETA: 1s - loss: 7.6892 - acc: 0.510 - ETA: 1s - loss: 7.6369 - acc: 0.514 - ETA: 1s - loss: 7.7057 - acc: 0.509 - ETA: 1s - loss: 7.7156 - acc: 0.509 - ETA: 1s - loss: 7.7067 - acc: 0.510 - ETA: 1s - loss: 7.7019 - acc: 0.510 - ETA: 1s - loss: 7.7460 - acc: 0.507 - ETA: 1s - loss: 7.6723 - acc: 0.512 - ETA: 1s - loss: 7.6842 - acc: 0.512 - ETA: 1s - loss: 7.6940 - acc: 0.511 - ETA: 1s - loss: 7.6718 - acc: 0.512 - ETA: 1s - loss: 7.6906 - acc: 0.511 - ETA: 0s - loss: 7.6953 - acc: 0.510 - ETA: 0s - loss: 7.7358 - acc: 0.507 - ETA: 0s - loss: 7.7129 - acc: 0.509 - ETA: 0s - loss: 7.6711 - acc: 0.512 - ETA: 0s - loss: 7.6805 - acc: 0.511 - ETA: 0s - loss: 7.6805 - acc: 0.511 - ETA: 0s - loss: 7.6974 - acc: 0.510 - ETA: 0s - loss: 7.7269 - acc: 0.508 - ETA: 0s - loss: 7.7253 - acc: 0.509 - ETA: 0s - loss: 7.7707 - acc: 0.506 - ETA: 0s - loss: 7.7714 - acc: 0.506 - ETA: 0s - loss: 7.7784 - acc: 0.505 - ETA: 0s - loss: 7.7679 - acc: 0.506 - ETA: 0s - loss: 7.7907 - acc: 0.505 - ETA: 0s - loss: 7.7753 - acc: 0.506 - ETA: 0s - loss: 7.8150 - acc: 0.503 - ETA: 0s - loss: 7.8011 - acc: 0.504 - ETA: 0s - loss: 7.8015 - acc: 0.5049Epoch 00013: val_loss improved from 8.60077 to 8.48838, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 7.8104 - acc: 0.5043 - val_loss: 8.4884 - val_acc: 0.4072
# Epoch 15/20
# 6480/6680 [============================>.] - ETA: 3s - loss: 6.4474 - acc: 0.600 - ETA: 2s - loss: 8.4404 - acc: 0.470 - ETA: 1s - loss: 7.8602 - acc: 0.507 - ETA: 1s - loss: 7.6619 - acc: 0.518 - ETA: 1s - loss: 7.5619 - acc: 0.525 - ETA: 1s - loss: 7.5240 - acc: 0.527 - ETA: 1s - loss: 7.4518 - acc: 0.531 - ETA: 1s - loss: 7.4616 - acc: 0.532 - ETA: 1s - loss: 7.4968 - acc: 0.529 - ETA: 1s - loss: 7.6554 - acc: 0.519 - ETA: 1s - loss: 7.6944 - acc: 0.516 - ETA: 1s - loss: 7.6744 - acc: 0.517 - ETA: 1s - loss: 7.7037 - acc: 0.514 - ETA: 1s - loss: 7.5872 - acc: 0.522 - ETA: 1s - loss: 7.6050 - acc: 0.520 - ETA: 1s - loss: 7.6159 - acc: 0.520 - ETA: 1s - loss: 7.6274 - acc: 0.519 - ETA: 0s - loss: 7.6418 - acc: 0.518 - ETA: 0s - loss: 7.6435 - acc: 0.518 - ETA: 0s - loss: 7.6620 - acc: 0.517 - ETA: 0s - loss: 7.6539 - acc: 0.518 - ETA: 0s - loss: 7.6444 - acc: 0.518 - ETA: 0s - loss: 7.6489 - acc: 0.518 - ETA: 0s - loss: 7.6890 - acc: 0.516 - ETA: 0s - loss: 7.6789 - acc: 0.516 - ETA: 0s - loss: 7.6382 - acc: 0.519 - ETA: 0s - loss: 7.6493 - acc: 0.518 - ETA: 0s - loss: 7.6631 - acc: 0.517 - ETA: 0s - loss: 7.7186 - acc: 0.513 - ETA: 0s - loss: 7.7323 - acc: 0.512 - ETA: 0s - loss: 7.7454 - acc: 0.511 - ETA: 0s - loss: 7.7449 - acc: 0.510 - ETA: 0s - loss: 7.7583 - acc: 0.509 - ETA: 0s - loss: 7.7620 - acc: 0.509 - ETA: 0s - loss: 7.7308 - acc: 0.511 - ETA: 0s - loss: 7.7556 - acc: 0.5102Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 7.7466 - acc: 0.5103 - val_loss: 8.4977 - val_acc: 0.4120
# Epoch 16/20
# 6500/6680 [============================>.] - ETA: 1s - loss: 6.4564 - acc: 0.600 - ETA: 2s - loss: 7.5255 - acc: 0.530 - ETA: 1s - loss: 7.5440 - acc: 0.527 - ETA: 1s - loss: 7.5683 - acc: 0.525 - ETA: 1s - loss: 7.5827 - acc: 0.522 - ETA: 1s - loss: 7.3284 - acc: 0.537 - ETA: 1s - loss: 7.3674 - acc: 0.534 - ETA: 1s - loss: 7.5163 - acc: 0.525 - ETA: 1s - loss: 7.6309 - acc: 0.518 - ETA: 1s - loss: 7.6794 - acc: 0.516 - ETA: 1s - loss: 7.6413 - acc: 0.518 - ETA: 1s - loss: 7.6173 - acc: 0.519 - ETA: 1s - loss: 7.6531 - acc: 0.517 - ETA: 1s - loss: 7.6155 - acc: 0.520 - ETA: 1s - loss: 7.5652 - acc: 0.523 - ETA: 1s - loss: 7.6318 - acc: 0.519 - ETA: 1s - loss: 7.6779 - acc: 0.516 - ETA: 1s - loss: 7.6829 - acc: 0.516 - ETA: 1s - loss: 7.6589 - acc: 0.517 - ETA: 0s - loss: 7.6716 - acc: 0.516 - ETA: 0s - loss: 7.6812 - acc: 0.515 - ETA: 0s - loss: 7.6846 - acc: 0.515 - ETA: 0s - loss: 7.6910 - acc: 0.513 - ETA: 0s - loss: 7.7048 - acc: 0.512 - ETA: 0s - loss: 7.6712 - acc: 0.514 - ETA: 0s - loss: 7.6401 - acc: 0.516 - ETA: 0s - loss: 7.6251 - acc: 0.517 - ETA: 0s - loss: 7.5873 - acc: 0.520 - ETA: 0s - loss: 7.5826 - acc: 0.520 - ETA: 0s - loss: 7.6098 - acc: 0.518 - ETA: 0s - loss: 7.6267 - acc: 0.517 - ETA: 0s - loss: 7.6343 - acc: 0.516 - ETA: 0s - loss: 7.6284 - acc: 0.516 - ETA: 0s - loss: 7.5960 - acc: 0.518 - ETA: 0s - loss: 7.6201 - acc: 0.516 - ETA: 0s - loss: 7.6072 - acc: 0.517 - ETA: 0s - loss: 7.6070 - acc: 0.5169Epoch 00015: val_loss improved from 8.48838 to 8.35257, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 7.6186 - acc: 0.5160 - val_loss: 8.3526 - val_acc: 0.4287
# Epoch 17/20
# 6580/6680 [============================>.] - ETA: 2s - loss: 6.4477 - acc: 0.600 - ETA: 1s - loss: 6.2764 - acc: 0.605 - ETA: 1s - loss: 7.1034 - acc: 0.550 - ETA: 1s - loss: 7.4223 - acc: 0.530 - ETA: 1s - loss: 7.3674 - acc: 0.532 - ETA: 1s - loss: 7.3713 - acc: 0.530 - ETA: 1s - loss: 7.5046 - acc: 0.521 - ETA: 1s - loss: 7.3671 - acc: 0.530 - ETA: 1s - loss: 7.3143 - acc: 0.533 - ETA: 1s - loss: 7.2691 - acc: 0.536 - ETA: 1s - loss: 7.3093 - acc: 0.535 - ETA: 1s - loss: 7.3241 - acc: 0.534 - ETA: 1s - loss: 7.3043 - acc: 0.536 - ETA: 1s - loss: 7.3126 - acc: 0.535 - ETA: 1s - loss: 7.3310 - acc: 0.534 - ETA: 1s - loss: 7.3913 - acc: 0.531 - ETA: 1s - loss: 7.4492 - acc: 0.527 - ETA: 0s - loss: 7.4627 - acc: 0.526 - ETA: 0s - loss: 7.4507 - acc: 0.527 - ETA: 0s - loss: 7.4863 - acc: 0.525 - ETA: 0s - loss: 7.4624 - acc: 0.527 - ETA: 0s - loss: 7.4940 - acc: 0.525 - ETA: 0s - loss: 7.4501 - acc: 0.527 - ETA: 0s - loss: 7.4523 - acc: 0.527 - ETA: 0s - loss: 7.4424 - acc: 0.528 - ETA: 0s - loss: 7.4198 - acc: 0.529 - ETA: 0s - loss: 7.4045 - acc: 0.530 - ETA: 0s - loss: 7.4249 - acc: 0.528 - ETA: 0s - loss: 7.4741 - acc: 0.526 - ETA: 0s - loss: 7.4411 - acc: 0.528 - ETA: 0s - loss: 7.4749 - acc: 0.526 - ETA: 0s - loss: 7.4713 - acc: 0.526 - ETA: 0s - loss: 7.4927 - acc: 0.525 - ETA: 0s - loss: 7.4798 - acc: 0.525 - ETA: 0s - loss: 7.4696 - acc: 0.526 - ETA: 0s - loss: 7.5141 - acc: 0.5240Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 7.5349 - acc: 0.5228 - val_loss: 8.3840 - val_acc: 0.4263
# Epoch 18/20
# 6540/6680 [============================>.] - ETA: 1s - loss: 8.0640 - acc: 0.500 - ETA: 1s - loss: 6.3900 - acc: 0.600 - ETA: 1s - loss: 6.9726 - acc: 0.563 - ETA: 1s - loss: 7.3478 - acc: 0.541 - ETA: 1s - loss: 7.2005 - acc: 0.550 - ETA: 1s - loss: 7.2807 - acc: 0.545 - ETA: 1s - loss: 7.5731 - acc: 0.528 - ETA: 1s - loss: 7.5054 - acc: 0.531 - ETA: 1s - loss: 7.3150 - acc: 0.543 - ETA: 1s - loss: 7.2644 - acc: 0.544 - ETA: 1s - loss: 7.3148 - acc: 0.542 - ETA: 1s - loss: 7.3109 - acc: 0.542 - ETA: 1s - loss: 7.3374 - acc: 0.540 - ETA: 1s - loss: 7.3408 - acc: 0.540 - ETA: 1s - loss: 7.4017 - acc: 0.536 - ETA: 1s - loss: 7.3936 - acc: 0.536 - ETA: 1s - loss: 7.4458 - acc: 0.533 - ETA: 1s - loss: 7.4623 - acc: 0.532 - ETA: 0s - loss: 7.4503 - acc: 0.533 - ETA: 0s - loss: 7.4580 - acc: 0.532 - ETA: 0s - loss: 7.4900 - acc: 0.530 - ETA: 0s - loss: 7.4273 - acc: 0.534 - ETA: 0s - loss: 7.4319 - acc: 0.534 - ETA: 0s - loss: 7.4283 - acc: 0.534 - ETA: 0s - loss: 7.4512 - acc: 0.533 - ETA: 0s - loss: 7.4264 - acc: 0.534 - ETA: 0s - loss: 7.4276 - acc: 0.534 - ETA: 0s - loss: 7.4660 - acc: 0.532 - ETA: 0s - loss: 7.4468 - acc: 0.533 - ETA: 0s - loss: 7.4671 - acc: 0.531 - ETA: 0s - loss: 7.5038 - acc: 0.529 - ETA: 0s - loss: 7.4732 - acc: 0.531 - ETA: 0s - loss: 7.4549 - acc: 0.532 - ETA: 0s - loss: 7.4713 - acc: 0.530 - ETA: 0s - loss: 7.5141 - acc: 0.527 - ETA: 0s - loss: 7.5262 - acc: 0.5269Epoch 00017: val_loss improved from 8.35257 to 8.29623, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 7.5113 - acc: 0.5277 - val_loss: 8.2962 - val_acc: 0.4275
# Epoch 19/20
# 6600/6680 [============================>.] - ETA: 2s - loss: 4.8355 - acc: 0.700 - ETA: 1s - loss: 7.1086 - acc: 0.550 - ETA: 1s - loss: 6.9311 - acc: 0.563 - ETA: 1s - loss: 7.0947 - acc: 0.553 - ETA: 1s - loss: 7.2232 - acc: 0.545 - ETA: 1s - loss: 7.2768 - acc: 0.540 - ETA: 1s - loss: 7.2892 - acc: 0.540 - ETA: 1s - loss: 7.2627 - acc: 0.542 - ETA: 1s - loss: 7.3108 - acc: 0.538 - ETA: 1s - loss: 7.3068 - acc: 0.538 - ETA: 1s - loss: 7.3660 - acc: 0.534 - ETA: 1s - loss: 7.4791 - acc: 0.528 - ETA: 1s - loss: 7.4402 - acc: 0.530 - ETA: 1s - loss: 7.3857 - acc: 0.534 - ETA: 1s - loss: 7.3570 - acc: 0.536 - ETA: 1s - loss: 7.3213 - acc: 0.539 - ETA: 1s - loss: 7.3361 - acc: 0.538 - ETA: 1s - loss: 7.3319 - acc: 0.538 - ETA: 1s - loss: 7.3510 - acc: 0.537 - ETA: 0s - loss: 7.3551 - acc: 0.537 - ETA: 0s - loss: 7.3109 - acc: 0.540 - ETA: 0s - loss: 7.3931 - acc: 0.535 - ETA: 0s - loss: 7.3427 - acc: 0.538 - ETA: 0s - loss: 7.3117 - acc: 0.540 - ETA: 0s - loss: 7.3472 - acc: 0.538 - ETA: 0s - loss: 7.3660 - acc: 0.537 - ETA: 0s - loss: 7.3828 - acc: 0.536 - ETA: 0s - loss: 7.3588 - acc: 0.537 - ETA: 0s - loss: 7.3872 - acc: 0.536 - ETA: 0s - loss: 7.3966 - acc: 0.535 - ETA: 0s - loss: 7.3828 - acc: 0.536 - ETA: 0s - loss: 7.4245 - acc: 0.533 - ETA: 0s - loss: 7.4444 - acc: 0.532 - ETA: 0s - loss: 7.4362 - acc: 0.533 - ETA: 0s - loss: 7.5031 - acc: 0.528 - ETA: 0s - loss: 7.4858 - acc: 0.530 - ETA: 0s - loss: 7.4929 - acc: 0.529 - ETA: 0s - loss: 7.4949 - acc: 0.5295Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 7.5018 - acc: 0.5292 - val_loss: 8.3156 - val_acc: 0.4287
# Epoch 20/20
# 6660/6680 [============================>.] - ETA: 1s - loss: 6.4474 - acc: 0.600 - ETA: 2s - loss: 7.1638 - acc: 0.555 - ETA: 2s - loss: 7.2036 - acc: 0.550 - ETA: 1s - loss: 7.4254 - acc: 0.535 - ETA: 1s - loss: 7.1681 - acc: 0.551 - ETA: 1s - loss: 7.4783 - acc: 0.533 - ETA: 1s - loss: 7.5095 - acc: 0.531 - ETA: 1s - loss: 7.5428 - acc: 0.529 - ETA: 1s - loss: 7.4917 - acc: 0.532 - ETA: 1s - loss: 7.5049 - acc: 0.532 - ETA: 1s - loss: 7.4518 - acc: 0.535 - ETA: 1s - loss: 7.5498 - acc: 0.529 - ETA: 1s - loss: 7.5115 - acc: 0.531 - ETA: 1s - loss: 7.5237 - acc: 0.531 - ETA: 1s - loss: 7.4792 - acc: 0.533 - ETA: 1s - loss: 7.4471 - acc: 0.535 - ETA: 1s - loss: 7.3939 - acc: 0.538 - ETA: 1s - loss: 7.3939 - acc: 0.538 - ETA: 0s - loss: 7.4068 - acc: 0.537 - ETA: 0s - loss: 7.3863 - acc: 0.538 - ETA: 0s - loss: 7.3894 - acc: 0.537 - ETA: 0s - loss: 7.4081 - acc: 0.536 - ETA: 0s - loss: 7.4492 - acc: 0.533 - ETA: 0s - loss: 7.4263 - acc: 0.535 - ETA: 0s - loss: 7.4241 - acc: 0.535 - ETA: 0s - loss: 7.4148 - acc: 0.536 - ETA: 0s - loss: 7.3817 - acc: 0.538 - ETA: 0s - loss: 7.4053 - acc: 0.536 - ETA: 0s - loss: 7.3966 - acc: 0.536 - ETA: 0s - loss: 7.4096 - acc: 0.535 - ETA: 0s - loss: 7.4201 - acc: 0.534 - ETA: 0s - loss: 7.4301 - acc: 0.534 - ETA: 0s - loss: 7.4456 - acc: 0.532 - ETA: 0s - loss: 7.4528 - acc: 0.532 - ETA: 0s - loss: 7.4768 - acc: 0.530 - ETA: 0s - loss: 7.4748 - acc: 0.530 - ETA: 0s - loss: 7.4817 - acc: 0.5297Epoch 00019: val_loss improved from 8.29623 to 8.23561, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s - loss: 7.4786 - acc: 0.5299 - val_loss: 8.2356 - val_acc: 0.4335

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_acc', 'loss', 'acc', 'val_loss'])

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
## 加载具有最好验证loss的模型

VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### 测试模型
# 现在，我们可以测试此CNN在狗图像测试数据集中识别品种的效果如何。我们在下方打印出测试准确率。

# %%
# 获取测试数据集中每一个图像所预测的狗品种的index
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# 报告测试准确率
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 42.8230%

# %% [markdown]
# ### 使用模型预测狗的品种

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # 提取bottleneck特征
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # 获取预测向量
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # 返回此模型预测的狗的品种
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## 步骤 5: 建立一个CNN来分类狗的品种（使用迁移学习）
#
# 现在你将使用迁移学习来建立一个CNN，从而可以从图像中识别狗的品种。你的 CNN 在测试集上的准确率必须至少达到60%。
#
# 在步骤4中，我们使用了迁移学习来创建一个使用基于 VGG-16 提取的特征向量来搭建一个 CNN。在本部分内容中，你必须使用另一个预训练模型来搭建一个 CNN。为了让这个任务更易实现，我们已经预先对目前 keras 中可用的几种网络进行了预训练：
#
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# 这些文件被命名为为：
#
#     Dog{network}Data.npz
#
# 其中 `{network}` 可以是 `VGG19`、`Resnet50`、`InceptionV3` 或 `Xception` 中的一个。选择上方网络架构中的一个，下载相对应的bottleneck特征，并将所下载的文件保存在目录 `bottleneck_features/` 中。
#
#
# ### 【练习】获取模型的特征向量
#
# 在下方代码块中，通过运行下方代码提取训练、测试与验证集相对应的bottleneck特征。
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: 从另一个预训练的CNN获取bottleneck特征
bottleneck_features = np.load('bottleneck_features/DogInceptionV3Data.npz')
train_InceptionV3 = bottleneck_features['train']
valid_InceptionV3 = bottleneck_features['valid']
test_InceptionV3 = bottleneck_features['test']

# %% [markdown]
# ### 【练习】模型架构
#
# 建立一个CNN来分类狗品种。在你的代码单元块的最后，通过运行如下代码输出网络的结构：
#
#         <your model's name>.summary()
#
# ---
#
# <a id='question6'></a>
#
# ### __问题 6:__
#
#
# 在下方的代码块中尝试使用 Keras 搭建最终的网络架构，并回答你实现最终 CNN 架构的步骤与每一步的作用，并描述你在迁移学习过程中，使用该网络架构的原因。
#
#
# __回答:__
# 本人使用谷歌的inception v3版本,作为预训练模型进行迁移学习。使用迁移学习后，训练时间上升了，但是对比自己搭建一个类似架构并且训练的话，时间和硬件会花费不少，对比model.summary,第三步中使用的cnn Trainable params为19,195 但是使用了迁移学习训练之后 Trainable params 达到了50,886,789，是之前的2651倍，假如可以花费，时间消耗可能会到达之前的数千倍，而且显存需求会大很多。不同的与训练模型差别是不一样的,如inceptionV3的输出是5,5,2048，而VGG-19是7,7，512，对于普通训练来说，预训练节省了很多的时间，而且对最终结果来说，调参会相对的容易一些，因为后面需要自己调参的图像大小已经比较小了。
#
# 我在inception v3后面首先加了一个BN层，然后卷积池化，接着加入了一个dropout用来抑制过拟合，接着加入了一个卷积层和一个全局平均池化，最后假如Dense层分类激活，并且假如Dropout进行过拟合处理。训练了两轮70epoch 没有出现过拟合，最终在测试集上效果是75.5981%

# %%
np.load('bottleneck_features/DogInceptionV3Data.npz')['train'].shape[1:]
# Out:
# (5, 5, 2048)

# %%
np.load('bottleneck_features/DogVGG19Data.npz')['train'].shape[1:]
# Out:
# (7, 7, 512)

# %%
np.load('bottleneck_features/DogResnet50Data.npz')['train'].shape[1:]
# Out:
# (1, 1, 2048)

# %%
np.load('bottleneck_features/DogXceptionData.npz')['train'].shape[1:]
# Out:
# (7, 7, 2048)

# %%
### TODO: 定义你的框架
from keras import optimizers
InceptionV3_model = Sequential()
# VGG19_model.add(Conv2D(32, (2, 2), input_shape=(7,7,512)))
# VGG19_model.add(MaxPooling2D(pool_size=(2, 2)))

# # VGG19_model.add(Conv2D(32, (2, 2)))
# # VGG19_model.add(MaxPooling2D(pool_size=(2, 2)))


# VGG19_model.add(Flatten())
# # VGG19_model.add(Dense(64))
# VGG19_model.add(Activation('relu'))
# VGG19_model.add(Dropout(0.5))

# VGG19_model.add(Dense(133))
InceptionV3_model.add(BatchNormalization(
    axis=-1,
    momentum=0.99,
    epsilon=0.001,
    center=True,
    scale=True,
    beta_initializer='zeros',
    gamma_initializer='ones',
    moving_mean_initializer='zeros',
    moving_variance_initializer='ones',
    beta_regularizer=None,
    gamma_regularizer=None,
    beta_constraint=None,
    gamma_constraint=None,
    input_shape=train_InceptionV3.shape[1:]
))
InceptionV3_model.add(Conv2D(2048, (2, 2)))
InceptionV3_model.add(MaxPooling2D(pool_size=(2, 2),strides=(2,2)))
InceptionV3_model.add(Dropout(0.5))
InceptionV3_model.add(Conv2D(4096, (2, 2)))
InceptionV3_model.add(GlobalAveragePooling2D())
# InceptionV3_model.add(MaxPooling2D(pool_size=(2, 2)))
InceptionV3_model.add(Dense(133, activation='softmax'))
InceptionV3_model.add(Dropout(0.5))
# Resnet50_model.add(Conv2D(2048, (2, 2)))
# Resnet50_model.add(MaxPooling2D(pool_size=(2, 2)))
# Resnet50_model.add(GlobalAveragePooling2D())
# InceptionV3_model.add(Flatten())

# InceptionV3_model.add(Dense(133,activation='relu'))

InceptionV3_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 5, 5, 2048)        8192
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 2048)        16779264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 2048)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2, 2, 2048)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 1, 4096)        33558528
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               544901
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 133)               0
# =================================================================
# Total params: 50,890,885.0
# Trainable params: 50,886,789.0
# Non-trainable params: 4,096.0
# _________________________________________________________________

# %%
### TODO: 编译模型
InceptionV3_model.compile(loss = "categorical_crossentropy",
              optimizer=optimizers.SGD(lr=1e-6, momentum=0.9),
              metrics=['mean_squared_logarithmic_error', 'accuracy'])

# %% [markdown]
# ---
#
# ### 【练习】训练模型
#
# <a id='question7'></a>
#
# ### __问题 7:__
#
# 在下方代码单元中训练你的模型。使用模型检查点（model checkpointing）来储存具有最低验证集 loss 的模型。
#
# 当然，你也可以对训练集进行 [数据增强](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html) 以优化模型的表现，不过这不是必须的步骤。

# %%
from keras.callbacks import ModelCheckpoint  
### TODO: 训练模型
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.InceptionV3.hdf5', 
                               verbose=1, save_best_only=True)

inception_history=InceptionV3_model.fit(train_InceptionV3, train_targets, 
          validation_data=(valid_InceptionV3, valid_targets),
          epochs=70, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/70
# 2360/6680 [=========>....................] - ETA: 289s - loss: 11.7430 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0000e+0 - ETA: 153s - loss: 11.9154 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0000e+0 - ETA: 107s - loss: 11.8348 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0000e+0 - ETA: 84s - loss: 11.4458 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0000e+0 - ETA: 71s - loss: 11.4214 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0000e+ - ETA: 61s - loss: 11.3954 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0000e+ - ETA: 55s - loss: 11.3976 - mean_squared_logarithmic_error: 0.0046 - acc: 0.0000e+ - ETA: 50s - loss: 11.4498 - mean_squared_logarithmic_error: 0.0046 - acc: 0.0000e+ - ETA: 46s - loss: 11.2822 - mean_squared_logarithmic_error: 0.0046 - acc: 0.0000e+ - ETA: 43s - loss: 11.3451 - mean_squared_logarithmic_error: 0.0046 - acc: 0.0000e+ - ETA: 40s - loss: 11.0527 - mean_squared_logarithmic_error: 0.0047 - acc: 0.0000e+ - ETA: 38s - loss: 11.0728 - mean_squared_logarithmic_error: 0.0046 - acc: 0.0000e+ - ETA: 36s - loss: 11.1751 - mean_squared_logarithmic_error: 0.0046 - acc: 0.0000e+ - ETA: 33s - loss: 11.1091 - mean_squared_logarithmic_error: 0.0046 - acc: 0.0000e+ - ETA: 32s - loss: 11.0642 - mean_squared_logarithmic_error: 0.0046 - acc: 0.0031   - ETA: 31s - loss: 10.9540 - mean_squared_logarithmic_error: 0.0046 - acc: 0.00 - ETA: 30s - loss: 10.9856 - mean_squared_logarithmic_error: 0.0046 - acc: 0.00 - ETA: 29s - loss: 11.1698 - mean_squared_logarithmic_error: 0.0046 - acc: 0.00 - ETA: 28s - loss: 11.2323 - mean_squared_logarithmic_error: 0.0046 - acc: 0.00 - ETA: 27s - loss: 11.2066 - mean_squared_logarithmic_error: 0.0046 - acc: 0.00 - ETA: 26s - loss: 11.1649 - mean_squared_logarithmic_error: 0.0046 - acc: 0.00 - ETA: 25s - loss: 11.0598 - mean_squared_logarithmic_error: 0.0046 - acc: 0.00 - ETA: 25s - loss: 11.0211 - mean_squared_logarithmic_error: 0.0046 - acc: 0.00 - ETA: 24s - loss: 11.0209 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 24s - loss: 11.0352 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 24s - loss: 11.0487 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 23s - loss: 11.0690 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 23s - loss: 10.9932 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 22s - loss: 11.0378 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 22s - loss: 11.0631 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 22s - loss: 11.0557 - mean_squared_logarithmic_error: 0.0046 - acc: 0.01 - ETA: 21s - loss: 11.0206 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 21s - loss: 11.0117 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 21s - loss: 11.0073 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 21s - loss: 11.0112 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 21s - loss: 11.0038 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 20s - loss: 11.0316 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 20s - loss: 11.0810 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 20s - loss: 11.0615 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 19s - loss: 11.0676 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 19s - loss: 11.0633 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 19s - loss: 11.0219 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 19s - loss: 11.0258 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 19s - loss: 11.0228 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 18s - loss: 10.9623 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 18s - loss: 10.9733 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 18s - loss: 10.9862 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 18s - loss: 11.0108 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 18s - loss: 11.0553 - mean_squared_logarith ...
# 6680/6680 [==============================] - 21s - loss: 10.9825 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0079 - val_loss: 5.5229 - val_mean_squared_logarithmic_error: 0.0038 - val_acc: 0.0120
# Epoch 2/70
# 2240/6680 [=========>....................] - ETA: 16s - loss: 10.5125 - mean_squared_logarithmic_error: 0.0041 - acc: 0.05 - ETA: 16s - loss: 10.9602 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 17s - loss: 10.9558 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 17s - loss: 11.3528 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 17s - loss: 11.5146 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 17s - loss: 11.2893 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 17s - loss: 11.4902 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 17s - loss: 11.3860 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 16s - loss: 11.3972 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 16s - loss: 11.2510 - mean_squared_logarithmic_error: 0.0045 - acc: 0.02 - ETA: 16s - loss: 11.2635 - mean_squared_logarithmic_error: 0.0045 - acc: 0.02 - ETA: 16s - loss: 11.0002 - mean_squared_logarithmic_error: 0.0045 - acc: 0.02 - ETA: 16s - loss: 10.9973 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 16s - loss: 11.0462 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 16s - loss: 11.2432 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 16s - loss: 11.2529 - mean_squared_logarithmic_error: 0.0045 - acc: 0.02 - ETA: 16s - loss: 11.2402 - mean_squared_logarithmic_error: 0.0045 - acc: 0.02 - ETA: 16s - loss: 11.2081 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 16s - loss: 11.1329 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 16s - loss: 11.2270 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 16s - loss: 11.0950 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 16s - loss: 11.0507 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 16s - loss: 10.9855 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9114 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9376 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9258 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9985 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9617 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9448 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9422 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9492 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9493 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9613 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9517 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9519 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 10.9788 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 15s - loss: 11.0468 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.0390 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.0678 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.0730 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.0782 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.0755 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.0864 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.0954 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.1132 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.0950 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.1239 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.1025 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.0744 - mean_squared_logarithmic_error: 0.0045 - acc: 0.01 - ETA: 14s - loss: 11.0217 - mean_squ ...
# 6660/6680 [============================>.] - ETA: 5s - loss: 10.8630 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 5s - loss: 10.8642 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8632 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8564 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8573 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8559 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8493 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8463 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8448 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8416 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8392 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8416 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8421 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8510 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8482 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8502 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8460 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 4s - loss: 10.8427 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8458 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8477 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8454 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8472 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8475 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8534 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8543 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8632 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8485 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8519 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8557 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8540 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8477 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8488 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8484 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8520 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8645 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 3s - loss: 10.8618 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8626 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8648 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8625 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8576 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8540 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8540 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8539 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8439 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8499 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8450 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8419 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8476 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8454 - mean_squared_logarithmic_error: 0.0045 - acc: 0.011 - ETA: 2s - loss: 10.8467 - mean_squa ...
# 6680/6680 [==============================] - 20s - loss: 10.8012 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0123 - val_loss: 5.3508 - val_mean_squared_logarithmic_error: 0.0037 - val_acc: 0.0132
# Epoch 3/70
# 2420/6680 [=========>....................] - ETA: 16s - loss: 12.1230 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0000e+ - ETA: 15s - loss: 12.1493 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0000e+ - ETA: 15s - loss: 11.3021 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0100   - ETA: 16s - loss: 11.5359 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 16s - loss: 11.2265 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 16s - loss: 11.0933 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 16s - loss: 11.1867 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 16s - loss: 11.0996 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.9252 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 10.9845 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 11.0097 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 11.0720 - mean_squared_logarithmic_error: 0.0045 - acc: 0.00 - ETA: 15s - loss: 11.0765 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 11.0314 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 11.0719 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 11.0859 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 11.0193 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 11.0324 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 10.9649 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 11.0843 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 11.0288 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 10.9832 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 10.9691 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 10.9465 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 10.9287 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 10.9445 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 10.9240 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 10.8950 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 15s - loss: 10.9015 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9039 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9000 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.8862 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9251 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9226 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9635 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9565 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9730 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9271 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9835 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9730 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9801 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9610 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9402 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9202 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9290 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9746 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 11.0019 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9966 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.9906 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 14s - loss: 10.990 ...
# 6680/6680 [==============================] - 20s - loss: 10.7369 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0139 - val_loss: 5.1914 - val_mean_squared_logarithmic_error: 0.0037 - val_acc: 0.0168
# Epoch 4/70
# 2340/6680 [=========>....................] - ETA: 17s - loss: 14.4773 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0000e+ - ETA: 17s - loss: 12.0664 - mean_squared_logarithmic_error: 0.0042 - acc: 0.0000e+ - ETA: 17s - loss: 11.2259 - mean_squared_logarithmic_error: 0.0043 - acc: 0.0000e+ - ETA: 17s - loss: 11.1207 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0000e+ - ETA: 16s - loss: 10.9697 - mean_squared_logarithmic_error: 0.0043 - acc: 0.0083   - ETA: 16s - loss: 11.1678 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 16s - loss: 11.2129 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 16s - loss: 11.0442 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 11.0870 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 11.0816 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 11.0755 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 11.2243 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 11.0359 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 11.0410 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 11.1023 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 11.1644 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 11.1814 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 11.1255 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 11.1813 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.2076 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.2232 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.1448 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.1254 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0591 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0487 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0836 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0745 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0412 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0390 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0254 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0452 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0727 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0697 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 11.0497 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 14s - loss: 11.0188 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 11.0048 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 11.0185 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9978 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9506 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9735 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9715 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9854 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9832 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9205 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9394 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9156 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9367 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9336 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.9730 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 13s - loss ...
# 6660/6680 [============================>.] - ETA: 4s - loss: 10.9429 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9342 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9419 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9461 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9479 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9529 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9524 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9484 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9497 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9466 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9478 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9514 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9493 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9538 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9480 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9497 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 4s - loss: 10.9537 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 3s - loss: 10.9592 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 3s - loss: 10.9559 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 3s - loss: 10.9483 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 3s - loss: 10.9501 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 3s - loss: 10.9444 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 3s - loss: 10.9436 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 3s - loss: 10.9454 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 3s - loss: 10.9461 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 3s - loss: 10.9376 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 3s - loss: 10.9377 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 3s - loss: 10.9296 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 3s - loss: 10.9259 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 3s - loss: 10.9257 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 3s - loss: 10.9238 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 3s - loss: 10.9224 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 3s - loss: 10.9273 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9299 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9277 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9243 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9267 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9289 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9332 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9314 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9330 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9332 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9314 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9327 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9326 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9418 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9378 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9365 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9413 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 2s - loss: 10.9385 - mean_squa ...
# 6680/6680 [==============================] - 20s - loss: 10.9351 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0151 - val_loss: 5.0315 - val_mean_squared_logarithmic_error: 0.0037 - val_acc: 0.0192
# Epoch 5/70
# 2260/6680 [=========>....................] - ETA: 16s - loss: 9.1735 - mean_squared_logarithmic_error: 0.0047 - acc: 0.0000e+0 - ETA: 16s - loss: 10.0160 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0500  - ETA: 16s - loss: 9.6417 - mean_squared_logarithmic_error: 0.0045 - acc: 0.0500 - ETA: 16s - loss: 9.6028 - mean_squared_logarithmic_error: 0.0044 - acc: 0.050 - ETA: 17s - loss: 9.3296 - mean_squared_logarithmic_error: 0.0044 - acc: 0.050 - ETA: 16s - loss: 9.4227 - mean_squared_logarithmic_error: 0.0044 - acc: 0.041 - ETA: 16s - loss: 9.8310 - mean_squared_logarithmic_error: 0.0044 - acc: 0.035 - ETA: 16s - loss: 9.9360 - mean_squared_logarithmic_error: 0.0044 - acc: 0.037 - ETA: 16s - loss: 10.0582 - mean_squared_logarithmic_error: 0.0044 - acc: 0.03 - ETA: 16s - loss: 9.8787 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0400 - ETA: 16s - loss: 9.9022 - mean_squared_logarithmic_error: 0.0044 - acc: 0.036 - ETA: 16s - loss: 10.0595 - mean_squared_logarithmic_error: 0.0044 - acc: 0.03 - ETA: 16s - loss: 10.1428 - mean_squared_logarithmic_error: 0.0044 - acc: 0.03 - ETA: 16s - loss: 10.0668 - mean_squared_logarithmic_error: 0.0044 - acc: 0.03 - ETA: 16s - loss: 10.1373 - mean_squared_logarithmic_error: 0.0044 - acc: 0.03 - ETA: 16s - loss: 10.0942 - mean_squared_logarithmic_error: 0.0044 - acc: 0.03 - ETA: 16s - loss: 10.0063 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 16s - loss: 10.0894 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 16s - loss: 10.0829 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 16s - loss: 9.9753 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0250 - ETA: 15s - loss: 9.9995 - mean_squared_logarithmic_error: 0.0044 - acc: 0.022 - ETA: 15s - loss: 10.0369 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 15s - loss: 10.0803 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 15s - loss: 10.0521 - mean_squared_logarithmic_error: 0.0043 - acc: 0.02 - ETA: 15s - loss: 10.0522 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 15s - loss: 10.0420 - mean_squared_logarithmic_error: 0.0043 - acc: 0.02 - ETA: 15s - loss: 9.9885 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0196 - ETA: 15s - loss: 10.0577 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.1151 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.1356 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.1414 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 15s - loss: 10.1591 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 15s - loss: 10.1518 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 15s - loss: 10.2166 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2529 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2320 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2417 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2067 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2728 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2394 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2740 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2861 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3202 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3399 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3205 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2771 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2663 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2700 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.2886 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3060 ...
# 6680/6680 [==============================] - 20s - loss: 10.4933 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0162 - val_loss: 4.8784 - val_mean_squared_logarithmic_error: 0.0037 - val_acc: 0.0228
# Epoch 6/70
# 2220/6680 [========>.....................] - ETA: 18s - loss: 9.2204 - mean_squared_logarithmic_error: 0.0041 - acc: 0.0000e+0 - ETA: 18s - loss: 9.4280 - mean_squared_logarithmic_error: 0.0042 - acc: 0.0000e+0 - ETA: 17s - loss: 9.6936 - mean_squared_logarithmic_error: 0.0043 - acc: 0.0000e+0 - ETA: 17s - loss: 10.4484 - mean_squared_logarithmic_error: 0.0043 - acc: 0.0000e+ - ETA: 17s - loss: 10.5835 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0000e+ - ETA: 17s - loss: 10.6759 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0000e+ - ETA: 17s - loss: 10.6844 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0000e+ - ETA: 17s - loss: 10.7200 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0000e+ - ETA: 16s - loss: 10.8373 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0000e+ - ETA: 16s - loss: 10.5323 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0000e+ - ETA: 16s - loss: 10.3858 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0045   - ETA: 16s - loss: 10.4013 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 16s - loss: 10.2872 - mean_squared_logarithmic_error: 0.0044 - acc: 0.00 - ETA: 16s - loss: 10.1423 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.1826 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.0471 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 16s - loss: 10.1674 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.2211 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.2585 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.1770 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.1728 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.1767 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.1857 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.1988 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.1752 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.1675 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2120 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2630 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2307 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2130 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.1874 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2551 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2468 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2807 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2525 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.3060 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2393 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 14s - loss: 10.3091 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3589 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 14s - loss: 10.3882 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4032 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3588 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3830 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3730 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3629 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3467 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3428 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3749 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4030 - mean_squared_logarithmic_error: 0.0044 - acc ...
# 4460/6680 [===================>..........] - ETA: 11s - loss: 10.6199 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 11s - loss: 10.6319 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 11s - loss: 10.6251 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 11s - loss: 10.6309 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 11s - loss: 10.6403 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 11s - loss: 10.6416 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 11s - loss: 10.6487 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 11s - loss: 10.6528 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6343 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6312 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6339 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6402 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6407 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6604 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6722 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6778 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6689 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6761 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6669 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6689 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6694 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6822 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6881 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6854 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 10s - loss: 10.6980 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 9s - loss: 10.6856 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0169 - ETA: 9s - loss: 10.6885 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6737 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6788 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6832 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6669 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6585 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6711 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6677 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 9s - loss: 10.6583 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6451 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6395 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6480 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 9s - loss: 10.6645 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 9s - loss: 10.6586 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 9s - loss: 10.6685 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 9s - loss: 10.6622 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 8s - loss: 10.6696 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 8s - loss: 10.6527 - mean_squared_logarithmic_error: 0.0044 - acc: 0.015 - ETA: 8s - loss: 10.6449 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 8s - loss: 10.6260 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 8s - loss: 10.6191 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 8s - loss: 10.6194 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 8s - loss: 10.6270 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 8s - loss: 10.6475 - mean_squ ...
# 6660/6680 [============================>.] - ETA: 5s - loss: 10.5983 - mean_squared_logarithmic_error: 0.0044 - acc: 0.017 - ETA: 5s - loss: 10.5928 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 5s - loss: 10.5993 - mean_squared_logarithmic_error: 0.0044 - acc: 0.016 - ETA: 5s - loss: 10.6005 - mean_squared_logarithmic_error: 0.0044 - acc: 0.017 - ETA: 5s - loss: 10.5971 - mean_squared_logarithmic_error: 0.0044 - acc: 0.017 - ETA: 5s - loss: 10.5917 - mean_squared_logarithmic_error: 0.0044 - acc: 0.017 - ETA: 5s - loss: 10.5834 - mean_squared_logarithmic_error: 0.0044 - acc: 0.017 - ETA: 5s - loss: 10.5931 - mean_squared_logarithmic_error: 0.0044 - acc: 0.017 - ETA: 5s - loss: 10.5942 - mean_squared_logarithmic_error: 0.0044 - acc: 0.017 - ETA: 5s - loss: 10.5903 - mean_squared_logarithmic_error: 0.0044 - acc: 0.017 - ETA: 5s - loss: 10.5856 - mean_squared_logarithmic_error: 0.0044 - acc: 0.018 - ETA: 5s - loss: 10.5917 - mean_squared_logarithmic_error: 0.0044 - acc: 0.018 - ETA: 4s - loss: 10.5847 - mean_squared_logarithmic_error: 0.0044 - acc: 0.018 - ETA: 4s - loss: 10.5835 - mean_squared_logarithmic_error: 0.0044 - acc: 0.018 - ETA: 4s - loss: 10.5750 - mean_squared_logarithmic_error: 0.0044 - acc: 0.018 - ETA: 4s - loss: 10.5809 - mean_squared_logarithmic_error: 0.0044 - acc: 0.018 - ETA: 4s - loss: 10.5796 - mean_squared_logarithmic_error: 0.0044 - acc: 0.018 - ETA: 4s - loss: 10.5875 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 4s - loss: 10.5870 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 4s - loss: 10.5791 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 4s - loss: 10.5822 - mean_squared_logarithmic_error: 0.0044 - acc: 0.018 - ETA: 4s - loss: 10.5898 - mean_squared_logarithmic_error: 0.0044 - acc: 0.018 - ETA: 4s - loss: 10.5878 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 4s - loss: 10.5788 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 4s - loss: 10.5716 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 4s - loss: 10.5727 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 4s - loss: 10.5746 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 4s - loss: 10.5771 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 4s - loss: 10.5814 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 4s - loss: 10.5827 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5891 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5834 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5854 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5785 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5719 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5676 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5708 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5635 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5621 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5747 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5809 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5866 - mean_squared_logarithmic_error: 0.0044 - acc: 0.020 - ETA: 3s - loss: 10.5831 - mean_squared_logarithmic_error: 0.0044 - acc: 0.020 - ETA: 3s - loss: 10.5818 - mean_squared_logarithmic_error: 0.0044 - acc: 0.019 - ETA: 3s - loss: 10.5855 - mean_squared_logarithmic_error: 0.0044 - acc: 0.020 - ETA: 3s - loss: 10.5838 - mean_squared_logarithmic_error: 0.0044 - acc: 0.020 - ETA: 3s - loss: 10.5826 - mean_squared_logarithmic_error: 0.0044 - acc: 0.020 - ETA: 2s - loss: 10.5882 - mean_squared_logarithmic_error: 0.0044 - acc: 0.020 - ETA: 2s - loss: 10.5804 - mean_squared_logarithmic_error: 0.0044 - acc: 0.020 - ETA: 2s - loss: 10.5915 - mean_squa ...
# 6680/6680 [==============================] - 20s - loss: 10.5462 - mean_squared_logarithmic_error: 0.0044 - acc: 0.0198 - val_loss: 4.7262 - val_mean_squared_logarithmic_error: 0.0036 - val_acc: 0.0299
# Epoch 7/70
# 2240/6680 [=========>....................] - ETA: 18s - loss: 12.2194 - mean_squared_logarithmic_error: 0.0046 - acc: 0.0000e+ - ETA: 16s - loss: 10.6547 - mean_squared_logarithmic_error: 0.0042 - acc: 0.0333   - ETA: 16s - loss: 10.6674 - mean_squared_logarithmic_error: 0.0042 - acc: 0.02 - ETA: 16s - loss: 10.6479 - mean_squared_logarithmic_error: 0.0042 - acc: 0.02 - ETA: 16s - loss: 10.8275 - mean_squared_logarithmic_error: 0.0043 - acc: 0.02 - ETA: 16s - loss: 10.6080 - mean_squared_logarithmic_error: 0.0043 - acc: 0.02 - ETA: 16s - loss: 10.4509 - mean_squared_logarithmic_error: 0.0043 - acc: 0.02 - ETA: 16s - loss: 10.7249 - mean_squared_logarithmic_error: 0.0043 - acc: 0.02 - ETA: 16s - loss: 10.5254 - mean_squared_logarithmic_error: 0.0043 - acc: 0.02 - ETA: 16s - loss: 10.5346 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 16s - loss: 10.3217 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 16s - loss: 10.3922 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 16s - loss: 10.3429 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 16s - loss: 10.4330 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.4404 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.5348 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 16s - loss: 10.5107 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.4853 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 10.4800 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 10.5516 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 10.5805 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.5767 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.5258 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 15s - loss: 10.5357 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.5227 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.4172 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.3425 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2800 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.3131 - mean_squared_logarithmic_error: 0.0043 - acc: 0.01 - ETA: 15s - loss: 10.3260 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2693 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.2730 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.3099 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.3086 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 15s - loss: 10.3268 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3140 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 14s - loss: 10.3369 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3437 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.3904 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4214 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4088 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4404 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4104 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4354 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4257 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4236 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4130 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4147 - mean_squared_logarithmic_error: 0.0044 - acc: 0.02 - ETA: 14s - loss: 10.4590 - mean_squared_logarithmic_error: 0.0044 - acc: 0.01 - ETA: 14s - loss: 10.4683 -  ...
# ...
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.6415 - mean_squared_logarithmic_error: 0.0033 - acc: 0.33 - ETA: 0s - loss: 8.6379 - mean_squared_logarithmic_error: 0.0033 - acc: 0.33 - ETA: 0s - loss: 8.6388 - mean_squared_logarithmic_error: 0.0033 - acc: 0.33 - ETA: 0s - loss: 8.6381 - mean_squared_logarithmic_error: 0.0033 - acc: 0.33 - ETA: 0s - loss: 8.6446 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.6465 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.6457 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.6587 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.6522 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.6541 - mean_squared_logarithmic_error: 0.0033 - acc: 0.3295Epoch 00066: val_loss improved from 1.17530 to 1.15918, saving model to saved_models/weights.best.InceptionV3.hdf5
# 6680/6680 [==============================] - 19s - loss: 8.6499 - mean_squared_logarithmic_error: 0.0033 - acc: 0.3299 - val_loss: 1.1592 - val_mean_squared_logarithmic_error: 0.0015 - val_acc: 0.7281
# Epoch 68/70
# 3140/6680 [=============>................] - ETA: 17s - loss: 8.1504 - mean_squared_logarithmic_error: 0.0030 - acc: 0.350 - ETA: 17s - loss: 7.8800 - mean_squared_logarithmic_error: 0.0031 - acc: 0.400 - ETA: 17s - loss: 8.2633 - mean_squared_logarithmic_error: 0.0032 - acc: 0.333 - ETA: 17s - loss: 8.4801 - mean_squared_logarithmic_error: 0.0031 - acc: 0.337 - ETA: 17s - loss: 8.4384 - mean_squared_logarithmic_error: 0.0032 - acc: 0.330 - ETA: 16s - loss: 8.4034 - mean_squared_logarithmic_error: 0.0032 - acc: 0.321 - ETA: 16s - loss: 8.4826 - mean_squared_logarithmic_error: 0.0032 - acc: 0.327 - ETA: 16s - loss: 8.7271 - mean_squared_logarithmic_error: 0.0032 - acc: 0.320 - ETA: 16s - loss: 8.8890 - mean_squared_logarithmic_error: 0.0033 - acc: 0.304 - ETA: 16s - loss: 8.9079 - mean_squared_logarithmic_error: 0.0033 - acc: 0.307 - ETA: 16s - loss: 9.0735 - mean_squared_logarithmic_error: 0.0033 - acc: 0.303 - ETA: 15s - loss: 9.1729 - mean_squared_logarithmic_error: 0.0034 - acc: 0.297 - ETA: 15s - loss: 9.1569 - mean_squared_logarithmic_error: 0.0033 - acc: 0.297 - ETA: 15s - loss: 9.2506 - mean_squared_logarithmic_error: 0.0033 - acc: 0.289 - ETA: 15s - loss: 9.2718 - mean_squared_logarithmic_error: 0.0034 - acc: 0.285 - ETA: 15s - loss: 9.2740 - mean_squared_logarithmic_error: 0.0034 - acc: 0.281 - ETA: 15s - loss: 9.2542 - mean_squared_logarithmic_error: 0.0034 - acc: 0.282 - ETA: 15s - loss: 9.3281 - mean_squared_logarithmic_error: 0.0034 - acc: 0.281 - ETA: 15s - loss: 9.1997 - mean_squared_logarithmic_error: 0.0034 - acc: 0.292 - ETA: 15s - loss: 9.2299 - mean_squared_logarithmic_error: 0.0034 - acc: 0.294 - ETA: 15s - loss: 8.9922 - mean_squared_logarithmic_error: 0.0033 - acc: 0.307 - ETA: 15s - loss: 8.9977 - mean_squared_logarithmic_error: 0.0033 - acc: 0.303 - ETA: 15s - loss: 9.0633 - mean_squared_logarithmic_error: 0.0033 - acc: 0.306 - ETA: 15s - loss: 9.0582 - mean_squared_logarithmic_error: 0.0033 - acc: 0.303 - ETA: 14s - loss: 9.1582 - mean_squared_logarithmic_error: 0.0033 - acc: 0.302 - ETA: 14s - loss: 9.2476 - mean_squared_logarithmic_error: 0.0034 - acc: 0.295 - ETA: 14s - loss: 9.2308 - mean_squared_logarithmic_error: 0.0034 - acc: 0.290 - ETA: 14s - loss: 9.2173 - mean_squared_logarithmic_error: 0.0034 - acc: 0.292 - ETA: 14s - loss: 9.0995 - mean_squared_logarithmic_error: 0.0033 - acc: 0.300 - ETA: 14s - loss: 9.1217 - mean_squared_logarithmic_error: 0.0034 - acc: 0.297 - ETA: 14s - loss: 9.1011 - mean_squared_logarithmic_error: 0.0034 - acc: 0.298 - ETA: 14s - loss: 9.1577 - mean_squared_logarithmic_error: 0.0034 - acc: 0.294 - ETA: 14s - loss: 9.1228 - mean_squared_logarithmic_error: 0.0034 - acc: 0.299 - ETA: 14s - loss: 9.0760 - mean_squared_logarithmic_error: 0.0034 - acc: 0.301 - ETA: 13s - loss: 9.0921 - mean_squared_logarithmic_error: 0.0034 - acc: 0.300 - ETA: 13s - loss: 9.1228 - mean_squared_logarithmic_error: 0.0034 - acc: 0.297 - ETA: 13s - loss: 9.0389 - mean_squared_logarithmic_error: 0.0034 - acc: 0.301 - ETA: 13s - loss: 8.9902 - mean_squared_logarithmic_error: 0.0033 - acc: 0.304 - ETA: 13s - loss: 9.0124 - mean_squared_logarithmic_error: 0.0034 - acc: 0.304 - ETA: 13s - loss: 8.9543 - mean_squared_logarithmic_error: 0.0034 - acc: 0.305 - ETA: 13s - loss: 8.9961 - mean_squared_logarithmic_error: 0.0034 - acc: 0.304 - ETA: 13s - loss: 8.9473 - mean_squared_logarithmic_error: 0.0033 - acc: 0.307 - ETA: 13s - loss: 8.9294 - mean_squared_logarithmic_error: 0.0033 - acc: 0.310 - ETA: 13s - loss: 9.0025 - mean_squared_logarithmic_error: 0.0033 - acc: 0.307 - ETA: 13s - loss: 9.0142 - mean_squared_logarithmic_error: 0.0033 - acc: 0.306 - ETA: 13s - loss: 8.9927 - mean_squared_logarithmic_error: 0.0033 - acc: 0.307 - ETA: 12s - loss: 9.0004 - mean_squared_logarithmic_error: 0.0033 - acc: 0.307 - ETA: 12s - loss: 9.0011 - mean_squared_logarithmic_error: 0.0033 - acc: 0.306 - ETA: 12s - loss: 8.9751 - mean_squared_logarithmic_error: 0.0033 - acc: 0.308 - ETA: 12s - loss: 8.9731 - mean_squa ...
# 6680/6680 [==============================] - 19s - loss: 8.8815 - mean_squared_logarithmic_error: 0.0033 - acc: 0.3178 - val_loss: 1.1470 - val_mean_squared_logarithmic_error: 0.0014 - val_acc: 0.7317
# Epoch 69/70
# 3020/6680 [============>.................] - ETA: 18s - loss: 11.2103 - mean_squared_logarithmic_error: 0.0037 - acc: 0.20 - ETA: 17s - loss: 10.5281 - mean_squared_logarithmic_error: 0.0034 - acc: 0.30 - ETA: 17s - loss: 10.3133 - mean_squared_logarithmic_error: 0.0035 - acc: 0.28 - ETA: 17s - loss: 10.4515 - mean_squared_logarithmic_error: 0.0035 - acc: 0.27 - ETA: 17s - loss: 10.0930 - mean_squared_logarithmic_error: 0.0035 - acc: 0.29 - ETA: 17s - loss: 9.9327 - mean_squared_logarithmic_error: 0.0034 - acc: 0.3000 - ETA: 16s - loss: 9.6924 - mean_squared_logarithmic_error: 0.0033 - acc: 0.312 - ETA: 16s - loss: 9.6401 - mean_squared_logarithmic_error: 0.0033 - acc: 0.311 - ETA: 16s - loss: 9.3792 - mean_squared_logarithmic_error: 0.0033 - acc: 0.322 - ETA: 16s - loss: 9.3701 - mean_squared_logarithmic_error: 0.0033 - acc: 0.325 - ETA: 16s - loss: 9.2810 - mean_squared_logarithmic_error: 0.0033 - acc: 0.319 - ETA: 16s - loss: 8.9755 - mean_squared_logarithmic_error: 0.0032 - acc: 0.340 - ETA: 16s - loss: 8.9158 - mean_squared_logarithmic_error: 0.0032 - acc: 0.340 - ETA: 15s - loss: 8.8755 - mean_squared_logarithmic_error: 0.0032 - acc: 0.344 - ETA: 15s - loss: 8.8304 - mean_squared_logarithmic_error: 0.0032 - acc: 0.342 - ETA: 15s - loss: 8.8491 - mean_squared_logarithmic_error: 0.0032 - acc: 0.352 - ETA: 15s - loss: 8.8552 - mean_squared_logarithmic_error: 0.0032 - acc: 0.347 - ETA: 15s - loss: 8.9102 - mean_squared_logarithmic_error: 0.0032 - acc: 0.341 - ETA: 15s - loss: 8.9010 - mean_squared_logarithmic_error: 0.0032 - acc: 0.338 - ETA: 15s - loss: 8.9533 - mean_squared_logarithmic_error: 0.0032 - acc: 0.335 - ETA: 15s - loss: 8.8716 - mean_squared_logarithmic_error: 0.0032 - acc: 0.337 - ETA: 15s - loss: 8.8948 - mean_squared_logarithmic_error: 0.0032 - acc: 0.338 - ETA: 15s - loss: 8.8922 - mean_squared_logarithmic_error: 0.0032 - acc: 0.335 - ETA: 15s - loss: 8.9600 - mean_squared_logarithmic_error: 0.0032 - acc: 0.330 - ETA: 14s - loss: 9.0851 - mean_squared_logarithmic_error: 0.0033 - acc: 0.322 - ETA: 14s - loss: 9.0372 - mean_squared_logarithmic_error: 0.0033 - acc: 0.326 - ETA: 14s - loss: 9.0330 - mean_squared_logarithmic_error: 0.0033 - acc: 0.325 - ETA: 14s - loss: 9.1033 - mean_squared_logarithmic_error: 0.0033 - acc: 0.322 - ETA: 14s - loss: 9.0159 - mean_squared_logarithmic_error: 0.0032 - acc: 0.323 - ETA: 14s - loss: 8.9958 - mean_squared_logarithmic_error: 0.0032 - acc: 0.322 - ETA: 14s - loss: 9.0347 - mean_squared_logarithmic_error: 0.0032 - acc: 0.321 - ETA: 14s - loss: 8.9154 - mean_squared_logarithmic_error: 0.0032 - acc: 0.327 - ETA: 14s - loss: 8.9247 - mean_squared_logarithmic_error: 0.0032 - acc: 0.327 - ETA: 14s - loss: 8.8601 - mean_squared_logarithmic_error: 0.0032 - acc: 0.327 - ETA: 14s - loss: 8.8737 - mean_squared_logarithmic_error: 0.0032 - acc: 0.324 - ETA: 13s - loss: 8.8861 - mean_squared_logarithmic_error: 0.0032 - acc: 0.320 - ETA: 13s - loss: 8.8852 - mean_squared_logarithmic_error: 0.0032 - acc: 0.318 - ETA: 13s - loss: 8.9698 - mean_squared_logarithmic_error: 0.0033 - acc: 0.313 - ETA: 13s - loss: 8.9684 - mean_squared_logarithmic_error: 0.0033 - acc: 0.313 - ETA: 13s - loss: 9.0268 - mean_squared_logarithmic_error: 0.0033 - acc: 0.311 - ETA: 13s - loss: 9.1057 - mean_squared_logarithmic_error: 0.0033 - acc: 0.305 - ETA: 13s - loss: 9.1136 - mean_squared_logarithmic_error: 0.0033 - acc: 0.306 - ETA: 13s - loss: 9.1442 - mean_squared_logarithmic_error: 0.0033 - acc: 0.304 - ETA: 13s - loss: 9.1491 - mean_squared_logarithmic_error: 0.0033 - acc: 0.304 - ETA: 13s - loss: 9.1512 - mean_squared_logarithmic_error: 0.0033 - acc: 0.304 - ETA: 13s - loss: 9.1376 - mean_squared_logarithmic_error: 0.0033 - acc: 0.302 - ETA: 13s - loss: 9.1393 - mean_squared_logarithmic_error: 0.0034 - acc: 0.300 - ETA: 12s - loss: 9.1194 - mean_squared_logarithmic_error: 0.0034 - acc: 0.299 - ETA: 12s - loss: 9.1505 - mean_squared_logarithmic_error: 0.0034 - acc: 0.295 - ETA: 12s - loss: 9.1239 - mean_squ ...
# 6660/6680 [============================>.] - ETA: 0s - loss: 8.7933 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.7924 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.7952 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.7921 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.7888 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.7830 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.7885 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.7854 - mean_squared_logarithmic_error: 0.0033 - acc: 0.32 - ETA: 0s - loss: 8.7913 - mean_squared_logarithmic_error: 0.0033 - acc: 0.3230Epoch 00068: val_loss improved from 1.14700 to 1.13123, saving model to saved_models/weights.best.InceptionV3.hdf5
# 6680/6680 [==============================] - 19s - loss: 8.7906 - mean_squared_logarithmic_error: 0.0033 - acc: 0.3232 - val_loss: 1.1312 - val_mean_squared_logarithmic_error: 0.0014 - val_acc: 0.7353
# Epoch 70/70
# 3180/6680 [=============>................] - ETA: 19s - loss: 9.3359 - mean_squared_logarithmic_error: 0.0031 - acc: 0.350 - ETA: 17s - loss: 7.2935 - mean_squared_logarithmic_error: 0.0032 - acc: 0.366 - ETA: 17s - loss: 7.3406 - mean_squared_logarithmic_error: 0.0032 - acc: 0.362 - ETA: 17s - loss: 7.7262 - mean_squared_logarithmic_error: 0.0032 - acc: 0.360 - ETA: 17s - loss: 7.7858 - mean_squared_logarithmic_error: 0.0032 - acc: 0.350 - ETA: 16s - loss: 8.1733 - mean_squared_logarithmic_error: 0.0034 - acc: 0.343 - ETA: 16s - loss: 7.8286 - mean_squared_logarithmic_error: 0.0033 - acc: 0.366 - ETA: 16s - loss: 8.0225 - mean_squared_logarithmic_error: 0.0033 - acc: 0.350 - ETA: 16s - loss: 8.1711 - mean_squared_logarithmic_error: 0.0032 - acc: 0.354 - ETA: 16s - loss: 8.1618 - mean_squared_logarithmic_error: 0.0032 - acc: 0.350 - ETA: 16s - loss: 8.5693 - mean_squared_logarithmic_error: 0.0032 - acc: 0.333 - ETA: 15s - loss: 8.3558 - mean_squared_logarithmic_error: 0.0032 - acc: 0.338 - ETA: 15s - loss: 8.4212 - mean_squared_logarithmic_error: 0.0032 - acc: 0.338 - ETA: 15s - loss: 8.1306 - mean_squared_logarithmic_error: 0.0031 - acc: 0.352 - ETA: 15s - loss: 8.2956 - mean_squared_logarithmic_error: 0.0032 - acc: 0.343 - ETA: 15s - loss: 8.2331 - mean_squared_logarithmic_error: 0.0032 - acc: 0.350 - ETA: 15s - loss: 8.2485 - mean_squared_logarithmic_error: 0.0032 - acc: 0.350 - ETA: 15s - loss: 8.3436 - mean_squared_logarithmic_error: 0.0032 - acc: 0.342 - ETA: 15s - loss: 8.3070 - mean_squared_logarithmic_error: 0.0032 - acc: 0.341 - ETA: 15s - loss: 8.2646 - mean_squared_logarithmic_error: 0.0031 - acc: 0.344 - ETA: 15s - loss: 8.3477 - mean_squared_logarithmic_error: 0.0032 - acc: 0.341 - ETA: 14s - loss: 8.4954 - mean_squared_logarithmic_error: 0.0032 - acc: 0.337 - ETA: 14s - loss: 8.5029 - mean_squared_logarithmic_error: 0.0032 - acc: 0.334 - ETA: 14s - loss: 8.5483 - mean_squared_logarithmic_error: 0.0032 - acc: 0.333 - ETA: 14s - loss: 8.5647 - mean_squared_logarithmic_error: 0.0032 - acc: 0.334 - ETA: 14s - loss: 8.5750 - mean_squared_logarithmic_error: 0.0032 - acc: 0.337 - ETA: 14s - loss: 8.5165 - mean_squared_logarithmic_error: 0.0033 - acc: 0.339 - ETA: 14s - loss: 8.4963 - mean_squared_logarithmic_error: 0.0033 - acc: 0.338 - ETA: 14s - loss: 8.4498 - mean_squared_logarithmic_error: 0.0033 - acc: 0.338 - ETA: 14s - loss: 8.4250 - mean_squared_logarithmic_error: 0.0033 - acc: 0.337 - ETA: 14s - loss: 8.4460 - mean_squared_logarithmic_error: 0.0033 - acc: 0.335 - ETA: 14s - loss: 8.4979 - mean_squared_logarithmic_error: 0.0033 - acc: 0.334 - ETA: 14s - loss: 8.4205 - mean_squared_logarithmic_error: 0.0032 - acc: 0.341 - ETA: 14s - loss: 8.4456 - mean_squared_logarithmic_error: 0.0033 - acc: 0.338 - ETA: 13s - loss: 8.4431 - mean_squared_logarithmic_error: 0.0032 - acc: 0.341 - ETA: 13s - loss: 8.4093 - mean_squared_logarithmic_error: 0.0032 - acc: 0.343 - ETA: 13s - loss: 8.3661 - mean_squared_logarithmic_error: 0.0032 - acc: 0.343 - ETA: 13s - loss: 8.3990 - mean_squared_logarithmic_error: 0.0032 - acc: 0.339 - ETA: 13s - loss: 8.3749 - mean_squared_logarithmic_error: 0.0032 - acc: 0.338 - ETA: 13s - loss: 8.3715 - mean_squared_logarithmic_error: 0.0032 - acc: 0.338 - ETA: 13s - loss: 8.3940 - mean_squared_logarithmic_error: 0.0033 - acc: 0.337 - ETA: 13s - loss: 8.4422 - mean_squared_logarithmic_error: 0.0033 - acc: 0.336 - ETA: 13s - loss: 8.4656 - mean_squared_logarithmic_error: 0.0033 - acc: 0.333 - ETA: 13s - loss: 8.5118 - mean_squared_logarithmic_error: 0.0033 - acc: 0.333 - ETA: 13s - loss: 8.5152 - mean_squared_logarithmic_error: 0.0033 - acc: 0.332 - ETA: 13s - loss: 8.4759 - mean_squared_logarithmic_error: 0.0033 - acc: 0.335 - ETA: 13s - loss: 8.4562 - mean_squared_logarithmic_error: 0.0033 - acc: 0.337 - ETA: 13s - loss: 8.4806 - mean_squared_logarithmic_error: 0.0033 - acc: 0.336 - ETA: 13s - loss: 8.5075 - mean_squared_logarithmic_error: 0.0033 - acc: 0.335 - ETA: 12s - loss: 8.5038 - mean_squa ...
# 6680/6680 [==============================] - 19s - loss: 8.5934 - mean_squared_logarithmic_error: 0.0032 - acc: 0.3356 - val_loss: 1.1190 - val_mean_squared_logarithmic_error: 0.0014 - val_acc: 0.7389

# %%
#前70 epoch
# summarize history for accuracy
plt.plot(inception_history.history['acc'])
plt.plot(inception_history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(inception_history.history['loss'])
plt.plot(inception_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#后70 epoch
# summarize history for accuracy
plt.plot(inception_history.history['acc'])
plt.plot(inception_history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(inception_history.history['loss'])
plt.plot(inception_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
### TODO: 加载具有最佳验证loss的模型权重
InceptionV3_model.load_weights('saved_models/weights.best.InceptionV3.hdf5')

# %% [markdown]
# ---
#
# ### 【练习】测试模型
#
# <a id='question8'></a>
#
# ### __问题 8:__
#
# 在狗图像的测试数据集上试用你的模型。确保测试准确率大于60%。

# %%
### TODO: 在测试集上计算分类准确率
# 获取测试数据集中每一个图像所预测的狗品种的index
InceptionV3_predictions = [np.argmax(InceptionV3_model.predict(np.expand_dims(feature, axis=0))) for feature in test_InceptionV3]

# 报告测试准确率
test_accuracy = 100*np.sum(np.array(InceptionV3_predictions)==np.argmax(test_targets, axis=1))/len(InceptionV3_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 68.8995%

# %% [markdown]
# ---
#
# ### 【练习】使用模型测试狗的品种
#
#
# 实现一个函数，它的输入为图像路径，功能为预测对应图像的类别，输出为你模型预测出的狗类别（`Affenpinscher`, `Afghan_hound` 等）。
#
# 与步骤5中的模拟函数类似，你的函数应当包含如下三个步骤：
#
# 1. 根据选定的模型载入图像特征（bottleneck features）
# 2. 将图像特征输输入到你的模型中，并返回预测向量。注意，在该向量上使用 argmax 函数可以返回狗种类的序号。
# 3. 使用在步骤0中定义的 `dog_names` 数组来返回对应的狗种类名称。
#
# 提取图像特征过程中使用到的函数可以在 `extract_bottleneck_features.py` 中找到。同时，他们应已在之前的代码块中被导入。根据你选定的 CNN 网络，你可以使用 `extract_{network}` 函数来获得对应的图像特征，其中 `{network}` 代表 `VGG19`, `Resnet50`, `InceptionV3`, 或 `Xception` 中的一个。
#
# ---
#
# <a id='question9'></a>
#
# ### __问题 9:__

# %%
### TODO: 写一个函数，该函数将图像的路径作为输入
def InceptionV3_predict_breed(img_path):
    # 提取bottleneck特征
    bottleneck_feature = extract_InceptionV3(path_to_tensor(img_path))
    # 获取预测向量
    predicted_vector = InceptionV3_model.predict(bottleneck_feature)
    # 返回此模型预测的狗的品种
    return dog_names[np.argmax(predicted_vector)]
### 然后返回此模型所预测的狗的品种

# %% [markdown]
# ---
#
# <a id='step6'></a>
# ## 步骤 6: 完成你的算法
#
#
#
# 实现一个算法，它的输入为图像的路径，它能够区分图像是否包含一个人、狗或两者都不包含，然后：
#
# - 如果从图像中检测到一只__狗__，返回被预测的品种。
# - 如果从图像中检测到__人__，返回最相像的狗品种。
# - 如果两者都不能在图像中检测到，输出错误提示。
#
# 我们非常欢迎你来自己编写检测图像中人类与狗的函数，你可以随意地使用上方完成的 `face_detector` 和 `dog_detector` 函数。你__需要__在步骤5使用你的CNN来预测狗品种。
#
# 下面提供了算法的示例输出，但你可以自由地设计自己的模型！
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
#
#
# <a id='question10'></a>
#
# ### __问题 10:__
#
# 在下方代码块中完成你的代码。
#
# ---

# %%
def show_pic(img_path):
    # 加载彩色（通道顺序为BGR）图像
    img = cv2.imread(img_path)


    # 将BGR图像转变为RGB图像以打印
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # 展示含有识别框的图像
    plt.imshow(cv_rgb)
    plt.show()

# %%
### TODO: 设计你的算法
def dog_or_human(img_path):
    if dog_detector(img_path)>0:
        print(InceptionV3_predict_breed(img_path))
    elif face_detector(img_path)>0:
        print('hello,human!')
        show_pic(img_path)
        print('You look like a ...')
        print(InceptionV3_predict_breed(img_path))
    else:
        print('An error just happend. Please check your dog didn\'t eat the paper!')
    
### 自由地使用所需的代码单元数吧

# %% [markdown]
# ---
# <a id='step7'></a>
# ## 步骤 7: 测试你的算法
#
# 在这个部分中，你将尝试一下你的新算法！算法认为__你__看起来像什么类型的狗？如果你有一只狗，它可以准确地预测你的狗的品种吗？如果你有一只猫，它会将你的猫误判为一只狗吗？
#
#
# <a id='question11'></a>
#
# ### __问题 11:__
#
# 在下方编写代码，用至少6张现实中的图片来测试你的算法。你可以使用任意照片，不过请至少使用两张人类图片（要征得当事人同意哦）和两张狗的图片。
# 同时请回答如下问题：
#
# 1. 输出结果比你预想的要好吗 :) ？或者更糟 :( ？
# 2. 提出至少三点改进你的模型的想法。

# %% [markdown]
# __回答:__ 比预想的差一点.改进模型的话,第一,人的识别率需要加强,侧面的话不一定能识别出人脸,第二,在模型方面,准确率打到了60%但是还是不够,所以在辨别狗品种时有偏差,3种狗当中,只有bulldog是识别出的,Cairn_terrier和Affenpinscher差别也不大,Field_spaniel和english_cocker_spaniel差别细微,很难识别.所以在迁移训练中最后的网络组建可以再更改一下,或者增加深度.第三,可以在训练过程加上数据增强,本人在尝试过程中遇到了点麻烦,不知道应该是在数据载入之后,在迁移训练之前,还是在迁移训练之后.

# %%
## TODO: 在你的电脑上，在步骤6中，至少在6张图片上运行你的算法。
## 自由地使用所需的代码单元数吧

# %%
dog_or_human('test/Walson.jpg')
# Out:
# hello,human!
# You look like a ...
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5

# %%
dog_or_human('test/Ming2.jpg')

# %%
dog_or_human('test/Bulldog.jpg')

# %%
dog_or_human('test/Cairn_terrier.jpg')

# %%
dog_or_human('test/cat.jpg')

# %%
dog_or_human('test/Field_spaniel.jpg')

# %%
dog_or_human('test/Jason.jpg')

# %% [markdown]
# **注意: 当你写完了所有的代码，并且回答了所有的问题。你就可以把你的 iPython Notebook 导出成 HTML 文件。你可以在菜单栏，这样导出File -> Download as -> HTML (.html)把这个 HTML 和这个 iPython notebook 一起做为你的作业提交。**
